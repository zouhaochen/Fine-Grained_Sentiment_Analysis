# %%
import pandas as pd
import numpy as np
import csv
import datetime 
import time
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from src import settings
import progressbar

retail_rocket_root_path = settings.DATA_ROOT_PATH + 'site_data/retail_rocket/'

# %%
# events_df = pd.read_csv(retail_rocket_root_path + 'raw_data/events.csv')
# category_tree_df = pd.read_csv(retail_rocket_root_path + 'raw_data/category_tree.csv')

# item_properties file 
# 417 053 unique items
# every row in the file has corresponding timestamp
# item properties file contain timestamp column because all of them are time dependent
# since properties may change over time, e.g. price, category, etc

# value of categoryid properties contain item category identifier
# value of available properties contains availability of the item ( 1: available, 0: ow)
# All numerical values were marked with "n" char at the beginning, and have 3 digits precision after decimal point


item_properties_1_df = pd.read_csv(retail_rocket_root_path + 'raw_data/item_properties_part1.csv')
item_properties_2_df = pd.read_csv(retail_rocket_root_path + 'raw_data/item_properties_part2.csv')
# timestamp,itemid,property,value

# 1435460400000,460429,categoryid,1338
# 1441508400000,206783,888,1116713 960601 n277.200
# 1439089200000,395014,400,n552.000 639502 n720.000 424566
# 1431226800000,59481,790,n15360.000
# 1431831600000,156781,917,828513
# 1436065200000,285026,available,0
# 1434250800000,89534,213,1121373
# 1431831600000,264312,6,319724
# 1433646000000,229370,202,1330310
# 1434250800000,98113,451,1141052 n48.000
# 1439089200000,450113,888,1038400 45956 n504.000

# %%
item_properties_1_df.head()
# Out:
#        timestamp  itemid    property                            value
# 0  1435460400000  460429  categoryid                             1338
# 1  1441508400000  206783         888          1116713 960601 n277.200
# 2  1439089200000  395014         400  n552.000 639502 n720.000 424566
# 3  1431226800000   59481         790                       n15360.000
# 4  1431831600000  156781         917                           828513

# %%
item_properties_2_df.head()
# Out:
#        timestamp  itemid property            value
# 0  1433041200000  183478      561           769062
# 1  1439694000000  132256      976  n26.400 1135780
# 2  1435460400000  420307      921  1149317 1257525
# 3  1431831600000  403324      917          1204143
# 4  1435460400000  230701      521           769062

# %%
# loc function: access a group of row and columns by labels.

# item_properties_1_df.property: dua ra item_id va properties cua item_properties_1_df
# 0           categoryid
# 1                  888
# 2                  400
# 3                  790
# 4                  917

# item_properties_1_df.property == 'categoryid'
#  0            True
#  1           False
#  2           False
#  3           False
#  4           False
#  5           False
#  6           False

# item_properties_1_df.loc[item_properties_1_df.property == 'categoryid', ['timestamp', 'itemid', 'value']]

# lấy ở item_properties_1_df voi property = categoryid voi cac gia tri tren cac cot timestamp, itemid va value

# giam gia tri tu 10999999 xuong con 426305 ban ghi

# Value of the "categoryid" property contains item category identifier.

item_cat_1 = item_properties_1_df.loc[item_properties_1_df.property == 'categoryid', ['timestamp', 'itemid', 'value']]
item_cat_1.head()
# Out:
#          timestamp  itemid value
# 0    1435460400000  460429  1338
# 140  1432436400000  281245  1277
# 151  1435460400000   35575  1059
# 189  1437274800000    8313  1147
# 197  1437879600000   55102    47

# %%
item_cat_2 = item_properties_2_df.loc[item_properties_2_df.property == 'categoryid', ['timestamp', 'itemid', 'value']]
item = item_cat_1.append(item_cat_2)
# y = item.drop_duplicates(['itemid', 'value']).groupby(['itemid', 'value']).count()
# y.head()
# # temp = item.loc[item.itemid == 25]
# # temp.sort_values(by=['timestamp'])
# # y = item.groupby(['itemid', 'value']).count()
# y.loc[y.timestamp == 1]

# %%
print "Record retrive from 1:", len(item_cat_1)
print "Record retrive from 1:", len(item_cat_2)
print "Total records:", len(item)
print(item[:10])
# Out:
# Record retrive from 1: 426305
# Record retrive from 1: 361909
# Total records: 788214
#          timestamp  itemid value
# 0    1435460400000  460429  1338
# 140  1432436400000  281245  1277
# 151  1435460400000   35575  1059
# 189  1437274800000    8313  1147
# 197  1437879600000   55102    47
# 213  1433041200000  397079   619
# 237  1436670000000  265036  1228
# 254  1437879600000  124459  1277
# 310  1437879600000  350508   546
# 325  1439089200000  221365  1226

# %%
# y.loc[:, ['itemid', 'value']] # type: pd.DataFrame

# xoa cac ban ghi trung nhau tren cac cot item_id va value, va loc lai lay cac gia tri tren 2 cot itemid va value.
z = item.drop_duplicates(['itemid', 'value']).loc[:, ['itemid', 'value']]
print z.head()
print "\n"
print "Length of items after remove duplicate:", len(z)
# y.to_dict()
# z.to_csv(retail_rocket_root_path + 'temp.txt', index=False, header=False)
# Out:
#      itemid value
# 0    460429  1338
# 140  281245  1277
# 151   35575  1059
# 189    8313  1147
# 197   55102    47
#
#
# Length of items after remove duplicate: 442432

# %%
# convert i2index.txt into dictionary
with open(retail_rocket_root_path + 'i2index.txt') as f: 
    active_item_dict = {int(line.split(',')[0]): int(line.split(',')[1]) for line in f}

# get list key from this dict.
active_item_list = active_item_dict.keys()

# %%
# remove cac phan tu trong z khong nam trong active item list (cac key lay tu file i2index.txt)
# z: item properties combine from 2 file.
s = z[z.itemid.isin(active_item_list)]
print 's head'
print s.head()

y = s.loc[:, 'itemid'].drop_duplicates() # xoa item_id trung nhau va loc tren cot itemid
print "y data type:",type(y)
print (y.head())
print len(y)
# Out:
# s head
#      itemid value
# 189    8313  1147
# 408   96660   498
# 504  244437   438
# 804  313481  1613
# 836  366108   498
# y data type: <class 'pandas.core.series.Series'>
# 189      8313
# 408     96660
# 504    244437
# 804    313481
# 836    366108
# Name: itemid, dtype: int64
# 83274

# %%
active_item_dict[8313]
# Out:
# 75509

# %%
# apply len tat ca cac phan tu cua s voi ham vo danh lambda.
# s.head()
#      itemid value
# 189    8313  1147
# 408   96660   498
# 504  244437   438
# 804  313481  1613
# 836  366108   498

# active item dict
# 393218: 27821,
#  393219: 30596,
#  393220: 2768,
#  152918: 36242,
#  6: 5054,

# thay the cac phan tu tung hang trong s tuong ung boi active_item_dict[x[0]], x[1]
# t moi thu duoc bao gom key cua active_item_dict va value cua s tuong ung.
t = s.apply(lambda x: [active_item_dict[x[0]], x[1]], axis=1, result_type='expand')
t.head()
# s.to_csv(retail_rocket_root_path + 'i2pcat.txt', index=False, header=False)
# Out:
#          0     1
# 189  75509  1147
# 408  42912   498
# 504  13362   438
# 804  33257  1613
# 836  60227   498

# %%
t.to_csv(retail_rocket_root_path + 'i2pcat.txt', index=False, header=False)
# i2pcat: item_id va categories tuong ung cua item do.
# voi item_id la item_id moi cua item khi chua mapping

# %%
# y la cac old item id.
print y.head()
x = y.to_list() # lay cac old item_id trong y
print len(x)
# print x[:5]
# Out:
# 189      8313
# 408     96660
# 504    244437
# 804    313481
# 836    366108
# Name: itemid, dtype: int64
# 83274

# %% [markdown]
# # Reading from event.csv

# %%
events_df = pd.read_csv(retail_rocket_root_path + 'raw_data/events.csv')
events_df.head()
# Out:
#        timestamp  visitorid event  itemid  transactionid
# 0  1433221332117     257597  view  355908            NaN
# 1  1433224214164     992329  view  248676            NaN
# 2  1433221999827     111016  view  318965            NaN
# 3  1433221955914     483717  view  253185            NaN
# 4  1433221337106     951259  view  367447            NaN

# %%
# get even_df tu trong danh sach cac events_df ma itemid do nam trong x (x la old item id) 
# (loai cac sk co cac item ko co trong x)
new_event_df = events_df[events_df.itemid.isin(x)]
# print(new_event_df.count()) -> 2094466
# print(events_df.count()) -> 2756101
new_event_df.to_csv(retail_rocket_root_path + 'raw_data/new_events.csv', index=False)
new_event_df.head()
# Out:
#        timestamp  visitorid event  itemid  transactionid
# 0  1433221332117     257597  view  355908            NaN
# 1  1433224214164     992329  view  248676            NaN
# 4  1433221337106     951259  view  367447            NaN
# 6  1433221923240     810725  view  443030            NaN
# 7  1433223291897     794181  view  439202            NaN

# %%
category_tree_df = pd.read_csv(retail_rocket_root_path + 'raw_data/category_tree.csv')
category_tree_df.head()
# Out:
#    categoryid  parentid
# 0        1016     213.0
# 1         809     169.0
# 2         570       9.0
# 3        1691     885.0
# 4         536    1691.0

# %%
# print category_tree_df['categoryid']
print type(category_tree_df['categoryid'])
# Out:
# <class 'pandas.core.series.Series'>

# %%
# lay ra cac phan tu trong category_tree_df ma parent la na. (ASK NHAT)????
category_tree_df.loc[category_tree_df.parentid.isna()]
# Out:
#       categoryid  parentid
# 5            231       NaN
# 589          791       NaN
# 861         1490       NaN
# 939          431       NaN
# 1111         755       NaN
# 1142         378       NaN
# 1208        1579       NaN
# 1211        1394       NaN
# 1322         659       NaN
# 1329        1057       NaN
# 1375         859       NaN
# 1392         803       NaN
# 1395         250       NaN
# 1476        1452       NaN
# 1484        1182       NaN
# 1490        1692       NaN
# 1614        1600       NaN
# 1616        1482       NaN
# 1622        1224       NaN
# 1623        1532       NaN
# 1624         395       NaN
# 1628         653       NaN
# 1629         140       NaN
# 1650        1698       NaN
# 1657         679       NaN

# %% [markdown]
# # Main: After that it change to retail_rocket data

# %%
retail_rocket_df = pd.read_csv(retail_rocket_root_path + '_explicit.clean.txt', header=None, names=['uid', 'itemid', 'time'])
print(retail_rocket_df.head())
# active_item_df = pd.read_csv(recobell_root_path + 'item_repr.txt', header=None, names=['itemid', 'repr'], delimiter=',', quotechar='|', skiprows=1)
# active_item_df.head()
# ASK NHAT
# _explicit.clean.txt: uid la user_id ban dau
# itemid la item_id ban dau
# Out:
#       uid  itemid           time
# 0  287857    5206  1433223236124
# 1  158090   10572  1433221078505
# 2  599528  356475  1433221941632
# 3  599528  356475  1433222276276
# 4  105775  312728  1433220880956

# %%
# load list key for i2index
with open(retail_rocket_root_path + 'i2index.txt') as f:
    active_item_dict = {int(line.split(',')[0]): int(line.split(',')[1]) for line in f}
active_item_list = active_item_dict.keys()
print "Number of items: ",len(active_item_list)
# Out:
# Number of items:  83274

# %%
# list key index from u2index.
with open(retail_rocket_root_path + 'u2index.txt') as f:
    active_user_dict = {int(line.split(',')[0]): int(line.split(',')[1]) for line in f}
active_user_list = active_user_dict.keys()
print "Number of users: ",len(active_user_list)
# Out:
# Number of users:  36751

# %%
print "length before filter: ", len(retail_rocket_df)
# loai bo tuong tac ma user khong co trong active_user_list
retail_rocket_df = retail_rocket_df[retail_rocket_df.uid.isin(active_user_list)]
retail_rocket_df = retail_rocket_df[retail_rocket_df.itemid.isin(active_item_list)]
print "length after filter: ", len(retail_rocket_df)
retail_rocket_df.head()
# Out:
# length before filter:  39939
# length after filter:  39939
#         uid  itemid           time
# 6    121688   15335  1433193500981
# 9    168685  111530  1433218757551
# 14  1203684   80953  1433217911121
# 16   273406  214912  1433174825959
# 17   615793  355994  1433175546693

# %%
print 'Sorting by uid and time giam dan (cang xa so voi hien tai):'
# a = retail_rocket_df.sort_values(by=['uid'])
retail_rocket_df_sort = retail_rocket_df.groupby(["uid"]).apply(lambda x: x.sort_values(["time"], ascending = False)).reset_index(drop=True)
print (retail_rocket_df_sort[:50])
# Out:
# Sorting by uid and time giam dan (cang xa so voi hien tai):
#      uid  itemid           time
# 0    155  389974  1442032680026
# 1    155  442601  1441952265950
# 2    155   41882  1441952264613
# 3    155  181405  1441951967871
# 4    155  452082  1441951937583
# 5    172   10034  1439602141686
# 6    172  465522  1439602141230
# 7    172  465522  1439601228324
# 8    172  465522  1439601219691
# 9    172   10034  1439599816912
# 10   318  133814  1435607785773
# 11   627  414182  1440103716892
# 12   627  414182  1440099961936
# 13   645   37029  1436226279887
# 14   648  207125  1436066053539
# 15   795  207825  1439244127846
# 16   795  207825  1439243682003
# 17   878  283916  1437716162516
# 18  2004  132772  1432016623960
# 19  2019  445559  1433368510965
# 20  2019  393144  1433368509996
# 21  2019  393144  1433316439898
# 22  2019  445559  1433316361979
# 23  2019  328869  1433311895274
# 24  2114  342264  1431908831703
# 25  2242  402047  1434339796245
# 26  2242  402047  1434335993380
# 27  2326   87702  1430690749035
# 28  3104  346661  1432273992770
# 29  3104  342086  1432273992723
# 30  3104  342086  1432273174918
# 31  3104  346661  1432273164453
# 32  3258  192948  1435067564357
# 33  3258   19278  1434999998471
# 34  3258  353548  1434999978158
# 35  3258   19278  1434999874325
# 36  3258  353548  1434999874230
# 37  3258   19278  1434999738975
# 38  3258  353548  1434999513058
# 39  3258   19278  1434999165724
# 40  3265  254193  1441750252074
# 41  3265  400707  1441750093014
# 42  3396  351841  1441820905463
# 43  3868  194593  1434500252395
# 44  3868  194593  1434500252300
# 45  3936  172894  1440384085490
# 46  3936  172894  1440381016080
# 47  3936   61237  1440358626193
# 48  4101  170353  1432168345279
# 49  4101  228066  1432168345247

# %%
active_user_dict[155]
# Out:
# 16518

# %%
# thay the rating ban dau boi user_id, item_id moi trong u2index va i2index.
retail_rocket_df_sort = retail_rocket_df_sort.apply(lambda x: [active_user_dict[x[0]], active_item_dict[x[1]]], axis=1, result_type='expand')
print(retail_rocket_df_sort[:50])
# Out:
#         0      1
# 0   16518  24797
# 1   16518  67373
# 2   16518  58774
# 3   16518  22559
# 4   16518  69597
# 5   16975   1400
# 6   16975   3598
# 7   16975   3598
# 8   16975   3598
# 9   16975   1400
# 10  12108   3382
# 11  18350  47924
# 12  18350  47924
# 13  31840   5298
# 14  30912   7015
# 15  15769  16973
# 16  15769  16973
# 17  34669   5982
# 18  21261   9076
# 19   1778   1729
# 20   1778   1540
# 21   1778   1540
# 22   1778   1729
# 23   1778  16390
# 24  27508   2468
# 25   7297  21207
# 26   7297  21207
# 27  23732  59669
# 28  27500  66385
# 29  27500  66537
# 30  27500  66537
# 31  27500  66385
# 32   9679  25684
# 33   9679  29037
# 34   9679  29364
# 35   9679  29037
# 36   9679  29364
# 37   9679  29037
# 38   9679  29364
# 39   9679  29037
# 40  22063  40930
# 41  22063   7042
# 42  22375  56807
# 43   7001  63987
# 44   7001  63987
# 45  18768   2722
# 46  18768   2722
# 47  18768  49336
# 48  28355  26885
# 49  28355   7677

# %%
print active_user_dict[121688]
print active_item_dict[15335]
# Out:
# 31
# 59933

# %% [markdown]
# # Sorting ratings.txt by time of implicit feedback

# %%
retail_rocket_df = pd.read_csv(retail_rocket_root_path + 'ratings.txt', header=None, names=['uid', 'itemid', 'time_implicit','number_im','time_explicit','number_ex'])
print(retail_rocket_df.head())
# Out:
#    uid  itemid  time_implicit  number_im  time_explicit  number_ex
# 0    0       0  1433224214164          1             -1          0
# 1    0    2921  1433224672007          1             -1          0
# 2    0    5692  1433225555976          1             -1          0
# 3    0    6353  1436503481324          4             -1          0
# 4    0    9442  1433730019241          2             -1          0

# %%
print 'Sorting by uid and time tang dan (tu qua khu cho den bay gio):'
# a = retail_rocket_df.sort_values(by=['uid'])
retail_rocket_df_sort = retail_rocket_df.groupby(["uid"]).apply(lambda x: x.sort_values(["time_implicit"], ascending = True)).reset_index(drop=True)
print (retail_rocket_df_sort[:50])
# Out:
# Sorting by uid and time giam dan (cang xa so voi hien tai):
#     uid  itemid  time_implicit  number_im  time_explicit  number_ex
# 0     0     919  1432781848232          1             -1          0
# 1     0    4244  1432782322169          1             -1          0
# 2     0       0  1433224214164          1             -1          0
# 3     0    2921  1433224672007          1             -1          0
# 4     0    5692  1433225555976          1             -1          0
# 5     0   10195  1433480149682          1             -1          0
# 6     0    1249  1433480524891          1             -1          0
# 7     0   10652  1433703062882          1             -1          0
# 8     0   10345  1433729380709          1             -1          0
# 9     0   10340  1433729489683          1             -1          0
# 10    0    9442  1433730019241          2             -1          0
# 11    0    8738  1433730231553          1             -1          0
# 12    0   13742  1433730402675          1             -1          0
# 13    0   17896  1433945313290          1             -1          0
# 14    0   17428  1433946626515          1             -1          0
# 15    0   19630  1434035218038          1             -1          0
# 16    0   20133  1434035349084          2             -1          0
# 17    0    2679  1434035926844          1             -1          0
# 18    0   10603  1434231531446          2             -1          0
# 19    0   29323  1435014240987          1             -1          0
# 20    0    8664  1435341565477          1             -1          0
# 21    0   27941  1436197608867          1             -1          0
# 22    0    6353  1436503481324          4             -1          0
# 23    0   83046  1438273381735          1             -1          0
# 24    1    2406  1433220801308          1             -1          0
# 25    1      90  1433220855897          1             -1          0
# 26    1     820  1433220865962          1             -1          0
# 27    1       1  1433220899221          1             -1          0
# 28    1      17  1433220908194          1             -1          0
# 29    2       2  1433224070841          1             -1          0
# 30    2    1360  1433224114165          1             -1          0
# 31    2    1993  1433224133537          1             -1          0
# 32    2     836  1433224149446          1             -1          0
# 33    2    2929  1433224189389          1             -1          0
# 34    2    1362  1433224587957          1             -1          0
# 35    2     832  1433224637266          1             -1          0
# 36    3   35250  1433117449676          1             -1          0
# 37    3    7817  1433117992014          1             -1          0
# 38    3   25745  1433118039876          2             -1          0
# 39    3    5706  1433118122199          1             -1          0
# 40    3   46406  1433118316198          1             -1          0
# 41    3   64218  1433118340293          1             -1          0
# 42    3    6790  1433118368657          1             -1          0
# 43    3    1135  1433118766688          1             -1          0
# 44    3      28  1433222357818          9             -1          0
# 45    3       3  1433223203944          1             -1          0
# 46    3   12876  1434469222934          1             -1          0
# 47    3   22973  1434469357015          1             -1          0
# 48    3    9154  1434469424172          1             -1          0
# 49    3   10023  1434469514651          1             -1          0

# %%
# in ra file 
retail_rocket_df_sort.to_csv(retail_rocket_root_path + 'ratings_sort_tuc.txt', index=False, header=False)

# %% [markdown]
# # user item explicit using for trainning without time series

# %%
#retail_rocket_df.to_csv(retail_rocket_root_path + 'ui_ex.xt', index=False, header=False)

# %%
# user item explicit for trainning with timestamp
retail_rocket_df_sort.to_csv(retail_rocket_root_path + 'ui_ex_timestamp_v2.txt', index=False, header=False)

# %%
# Generate using implicit dataset into ui_im_timestamp.txt

# %%
retail_rocket_df_implicit = pd.read_csv(retail_rocket_root_path + '_implicit.clean.txt', header=None, names=['uid', 'itemid', 'time'])
print(retail_rocket_df.head())
# Out:
#        uid  itemid           time
# 0  257597  355908  1433221332117
# 1  992329  248676  1433224214164
# 2  951259  367447  1433221337106
# 3  810725  443030  1433221923240
# 4  794181  439202  1433223291897

# %%
print "length before filter: ", len(retail_rocket_df_implicit)
# loai bo tuong tac ma user khong co trong active_user_list
retail_rocket_df_implicit = retail_rocket_df_implicit[retail_rocket_df_implicit.uid.isin(active_user_list)]
retail_rocket_df_implicit = retail_rocket_df_implicit[retail_rocket_df_implicit.itemid.isin(active_item_list)]
print "length after filter: ", len(retail_rocket_df_implicit)
retail_rocket_df_implicit.head()
# Out:
# length before filter:  2020318
# length after filter:  573756
#         uid  itemid           time
# 1    992329  248676  1433224214164
# 5    824915  428805  1433220899221
# 13  1398644  135256  1433224070841
# 16   125625   17655  1433223203944
# 18  1076270  262799  1433222147345

# %%
print 'Sorting by uid and time giam dan (cang xa so voi hien tai):'
# a = retail_rocket_df.sort_values(by=['uid'])
retail_rocket_df_implicit_sort = retail_rocket_df_implicit.groupby(["uid"]).apply(lambda x: x.sort_values(["time"], ascending = False)).reset_index(drop=True)
print (retail_rocket_df_implicit_sort[:5])
# Out:
# Sorting by uid and time giam dan (cang xa so voi hien tai):
#    uid  itemid           time
# 0   51  279059  1441495684069
# 1   51   49967  1441495634886
# 2   51  198762  1441495582729
# 3   51  429304  1441495416363
# 4   51  198762  1441495318252

# %%
# thay the rating ban dau boi user_id, item_id moi trong u2index va i2index.
retail_rocket_df_implicit_sort = retail_rocket_df_implicit_sort.apply(lambda x: [active_user_dict[x[0]], active_item_dict[x[1]]], axis=1, result_type='expand')
print(retail_rocket_df_implicit_sort[:50])
# Out:
#         0      1
# 0   21616  42605
# 1   21616  13063
# 2   21616   7821
# 3   21616  13153
# 4   21616   7821
# 5   21616  54900
# 6   23498   3389
# 7   23498  50849
# 8   23498  47531
# 9   23498  47531
# 10  23498   8883
# 11  23498  59189
# 12  23498    244
# 13  23498   8883
# 14  23498   3389
# 15  23498    244
# 16  23498  59189
# 17   6738  21505
# 18   6738  21505
# 19   6738    895
# 20   6738  21434
# 21   6738  21638
# 22   6738  21195
# 23   6738  18111
# 24  16518  53110
# 25  16518   9040
# 26  16518   2877
# 27  16518  23223
# 28  16518  13380
# 29  16518   1754
# 30  16518  13380
# 31   2113  51263
# 32   2113   1107
# 33   2113   8117
# 34   2113   7287
# 35   2113   7288
# 36  16975   3598
# 37  16975   3598
# 38  16975   3598
# 39  16975  21354
# 40  16975  19235
# 41  16975  11370
# 42  16975  33805
# 43  16975   1400
# 44  16975  16840
# 45  16975  33103
# 46  16975  33103
# 47  16975  33103
# 48  16975   1400
# 49  16975  21015

# %%
# user item explicit for trainning with timestamp
retail_rocket_df_implicit_sort.to_csv(retail_rocket_root_path + 'ui_im_timestamp_v2.txt', index=False, header=False)

# %%
# Running with time sequences.

# %%
import pandas as pd
import numpy as np
import csv
import datetime 
import time
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns
from src import settings
from sklearn import metrics

retail_rocket_root_path = settings.DATA_ROOT_PATH + 'site_data/retail_rocket/'

# %%
# khao sat tu bo data ban dau.
implicit_retail_rocket_df = pd.read_csv(retail_rocket_root_path + '_implicit.clean.txt', header=None, names=['uid', 'itemid', 'time'])
print(implicit_retail_rocket_df.head())
# Out:
#       uid  itemid           time
# 0  257597  355908  1433221332117
# 1  992329  248676  1433224214164
# 2  951259  367447  1433221337106
# 3  810725  443030  1433221923240
# 4  794181  439202  1433223291897

# %%
# load list key for i2index
with open(retail_rocket_root_path + 'i2index.txt') as f:
    active_item_dict = {int(line.split(',')[0]): int(line.split(',')[1]) for line in f}
active_item_list = active_item_dict.keys()
print "Number of items: ",len(active_item_list)
# Out:
# Number of items:  83274

# %%
# list key index from u2index.
with open(retail_rocket_root_path + 'u2index.txt') as f:
    active_user_dict = {int(line.split(',')[0]): int(line.split(',')[1]) for line in f}
active_user_list = active_user_dict.keys()
print "Number of users: ",len(active_user_list)
# Out:
# Number of users:  36751

# %%
print "length before filter: ", len(implicit_retail_rocket_df)
# loai bo tuong tac ma user, item khong co trong active_user_list va active_item_list.
implicit_retail_rocket_df = implicit_retail_rocket_df[implicit_retail_rocket_df.uid.isin(active_user_list)]
implicit_retail_rocket_df = implicit_retail_rocket_df[implicit_retail_rocket_df.itemid.isin(active_item_list)]
print "length after filter: ", len(implicit_retail_rocket_df)
# Out:
# length before filter:  2020318
# length after filter:  573756

# %%
implicit_retail_rocket_df = implicit_retail_rocket_df.groupby(["uid"]).apply(lambda x: x.sort_values(["uid","time"], ascending = True)).reset_index(drop=True)

# %%
implicit_retail_rocket_df[:20]
# Out:
#     uid  itemid           time
# 0    51  358388  1441495257511
# 1    51  198762  1441495318252
# 2    51  429304  1441495416363
# 3    51  198762  1441495582729
# 4    51   49967  1441495634886
# 5    51  279059  1441495684069
# 6    54  388096  1442338531705
# 7    54  283115  1442338665550
# 8    54   38965  1442338748248
# 9    54  319680  1442338841333
# 10   54  283115  1442339111712
# 11   54  388096  1442339814679
# 12   54  319680  1442351092285
# 13   54  442228  1442352963922
# 14   54  442228  1442360201962
# 15   54  249114  1442422337240
# 16   54   38965  1442538207379
# 17   64  141657  1434405111942
# 18   64  295653  1434407643196
# 19   64  233200  1434408004268

# %%
out_file = retail_rocket_root_path + "_implicit.filter.clean.txt"
implicit_retail_rocket_df.to_csv(out_file, header=None, index=None, sep=',')

# %% [markdown]
# # explicit dataset for preprocessing.

# %%
explicit_retail_rocket_df = pd.read_csv(retail_rocket_root_path + '_explicit.clean.txt', header=None, names=['uid', 'itemid', 'time'])
print(explicit_retail_rocket_df.head())
# Out:
#       uid  itemid           time
# 0  287857    5206  1433223236124
# 1  158090   10572  1433221078505
# 2  599528  356475  1433221941632
# 3  599528  356475  1433222276276
# 4  105775  312728  1433220880956

# %%
print "length before filter: ", len(explicit_retail_rocket_df)
# loai bo tuong tac ma user, item khong co trong active_user_list va active_item_list.
explicit_retail_rocket_df = explicit_retail_rocket_df[explicit_retail_rocket_df.uid.isin(active_user_list)]
explicit_retail_rocket_df = explicit_retail_rocket_df[explicit_retail_rocket_df.itemid.isin(active_item_list)]
print "length after filter: ", len(explicit_retail_rocket_df)
# Out:
# length before filter:  88886
# length after filter:  39939

# %%
explicit_retail_rocket_df = explicit_retail_rocket_df.groupby(["uid"]).apply(lambda x: x.sort_values(["uid","time"], ascending = True)).reset_index(drop=True)

# %%
explicit_retail_rocket_df[:20]
# Out:
#      uid  itemid           time
# 0    155  452082  1441951937583
# 1    155  181405  1441951967871
# 2    155   41882  1441952264613
# 3    155  442601  1441952265950
# 4    155  389974  1442032680026
# 5    172   10034  1439599816912
# 6    172  465522  1439601219691
# 7    172  465522  1439601228324
# 8    172  465522  1439602141230
# 9    172   10034  1439602141686
# 10   318  133814  1435607785773
# 11   627  414182  1440099961936
# 12   627  414182  1440103716892
# 13   645   37029  1436226279887
# 14   648  207125  1436066053539
# 15   795  207825  1439243682003
# 16   795  207825  1439244127846
# 17   878  283916  1437716162516
# 18  2004  132772  1432016623960
# 19  2019  328869  1433311895274

# %%
out_file = retail_rocket_root_path + "_explicit.filter.clean.txt"
explicit_retail_rocket_df.to_csv(out_file, header=None, index=None, sep=',')

# %%
# from _implicit.filter.clean.txt, _explicit.filter.clean.txt merge into one.
implicit_file = retail_rocket_root_path + "_implicit.filter.clean.txt"
explicit_file = retail_rocket_root_path + "_explicit.filter.clean.txt"

implicit_interacted_dict = {}
file_pointer = open(implicit_file, "r")  # reading from _implicit.clean.txt
    # b15f9e5, d9886b1, 1471066727
    # 8007201, e295b87, 1471156894

csv_reader = csv.reader(file_pointer, delimiter=',', quotechar='', quoting=csv.QUOTE_NONE)
for line in csv_reader:
    raw_uid = line[0]  # string
    raw_item_id = line[1]
    if raw_uid in implicit_interacted_dict:
        implicit_interacted_dict[raw_uid].add(raw_item_id)
    else:
        implicit_interacted_dict[raw_uid] = {raw_item_id}

# %%
implicit_interacted_dict["54"]
# Out:
# {'249114', '283115', '319680', '388096', '38965', '442228'}

# %%
# from _implicit.clean.txt, _explicit.clean.txt
# output: user_index_output, item_index_ouput
# ratings.txt
def gen_ratings_data_with_explicit(implicit_input, explicit_input, user_index_output, item_index_output, 
                                   output):
    # create uid blacklist
    interacted_dict = {}

    file_pointer = open(implicit_input, "r")  # reading from _implicit.clean.txt
    # b15f9e5, d9886b1, 1471066727
    # 8007201, e295b87, 1471156894

    csv_reader = csv.reader(file_pointer, delimiter=',', quotechar='', quoting=csv.QUOTE_NONE)
    for line in csv_reader:
        raw_uid = line[0]  # string
        raw_item_id = line[1]
        if raw_uid in interacted_dict:
            interacted_dict[raw_uid].add(raw_item_id)  # tao ra bo tu dien interact cho moi user.
            # co cau truc kieu uid => list item interacted by uid
        else:
            # interacted_dict[raw_uid] = type set()
            interacted_dict[raw_uid] = {raw_item_id}  # neu user chua co trong interacted_dict thi tao ra dict moi

    uid_blacklist = set()  # tap cac user co so luong item implicit tuong tac nho hon 5
    for uid in interacted_dict:  # moi user trong interacted_list
        if len(interacted_dict[uid]) < 5:  # so luong nho hon 5 thi them user do vao  black list
            uid_blacklist.add(uid)
    file_pointer.close()
    print("len uid_blacklist:", len(uid_blacklist))

    # convert uid, item_id
    logging.info("convert uid, item_id")

    # uid_dict, item_id_dict la anh xa tu raw_id sang id dang so nguyen tu 0 den n
    user_id_dict = {}
    item_id_dict = {}

    implicit_rating_dict = {}
    uid_count = 0
    item_id_count = 0

    file_pointer = open(implicit_input, "r")  # read file implict_clean
    csv_reader = csv.reader(file_pointer, delimiter=',', quotechar='', quoting=csv.QUOTE_NONE)
    # b15f9e5, d9886b1, 1471066727
    # 8007201, e295b87, 1471156894
    for line in csv_reader:
        raw_uid = line[0]  # string
        if raw_uid not in uid_blacklist:  # khong nam trong black list
            raw_item_id = line[1]  # item id
            raw_timestamp = line[2]  # time click
            if raw_uid not in user_id_dict:  # tao ra dict voi key la user_id => stt cua user do.
                user_id_dict[raw_uid] = uid_count
                uid_count += 1
            if raw_item_id not in item_id_dict:  # dict item: key la item_id => so tt cua item do
                item_id_dict[raw_item_id] = item_id_count
                item_id_count += 1

            # add user data to dict
            uid = user_id_dict[raw_uid]
            # int : lay ra uid moi cua user tuong ung voi raw_uid
            if uid in implicit_rating_dict:
                implicit_rating_dict[uid].append((item_id_dict[raw_item_id], raw_timestamp))
                # implicit_rating_dict: dict voi key la uid va value la mot mang voi moi phan tu la new_item_id, time_stamp
            else:
                implicit_rating_dict[uid] = [(item_id_dict[raw_item_id], raw_timestamp)]
    file_pointer.close()
    print("len user list:", len(user_id_dict))
    print("len item list:", len(item_id_dict))
    print("len implicit_rating_dict:", len(implicit_rating_dict))

    with open(user_index_output, 'w') as f:  # viet ra file 'u2index.txt'
        csv_writer = csv.writer(f, delimiter=',', quotechar='', quoting=csv.QUOTE_NONE)
        for k in user_id_dict:
            csv_writer.writerow([k, user_id_dict[k]])  # uid ban dau => uid moi.

    with open(item_index_output, 'w') as f:  # viet ra file 'i2index.txt'
        csv_writer = csv.writer(f, delimiter=',', quotechar='', quoting=csv.QUOTE_NONE)
        for k in item_id_dict:
            csv_writer.writerow([k, item_id_dict[k]])  # item id raw => itemid moi.
    # load explicit data put to explicit_rating_dict

    explicit_rating_dict = {}
    file_pointer = open(explicit_input, "r")  # reading from '_explicit.clean.txt'

    csv_reader = csv.reader(file_pointer, delimiter=',', quotechar='', quoting=csv.QUOTE_NONE)
    for line in csv_reader:  # moi dong trong bo du lieu explicit.
        raw_uid = line[0]  # raw uid
        raw_item_id = line[1]  # raw item id
        raw_timestamp = line[2]  # raw time stamp
        if (raw_uid in user_id_dict) and (raw_item_id in item_id_dict):
            uid = user_id_dict[raw_uid]  # id moi cua user
            if uid in explicit_rating_dict:  # tao ra explicit rating dict cho moi user.
                # voi key la uid moi (xay tu bo du lieu implicit
                # value tuong ung la item_id moi va raw time stamp
                explicit_rating_dict[uid].append((item_id_dict[raw_item_id], raw_timestamp))
            else:
                explicit_rating_dict[uid] = [(item_id_dict[raw_item_id], raw_timestamp)]
    file_pointer.close()

    # gen ratings data
    logging.info('gen ratings with explicit data')
    out_file = open(output, 'w')  # writing to file ratings.txt
    csv_writer = csv.writer(out_file, delimiter=',', quotechar='', quoting=csv.QUOTE_NONE)  # ratings.txt
    # format outfile rating.txt: raw_uid,raw_item_id,implicit_timestamp,num_implicicit,explicit_timestamp,num_explicit
    for uid in implicit_rating_dict:  # moi uid trong implicit rating dict.
        # check duplicate
        implicit_item_time_dict = {}
        explicit_item_time_dict = {}
        for his in implicit_rating_dict[uid]:  # implicit_rating_dict[uid]: mang cac cap new_itemid, time stamp
            item_id = his[0]
            timestamp = his[1]
            if item_id in implicit_item_time_dict:  # neu item_id nam trong implicit_item_time_dict
                if timestamp > implicit_item_time_dict[item_id][0]:
                    implicit_item_time_dict[item_id][0] = timestamp
                implicit_item_time_dict[item_id][1] += 1
            else:
                implicit_item_time_dict[item_id] = [timestamp, 1]
                # khoi tao dict gom key => mang 2 phan tu [timestamp, stt]
                # => cuoi cung thu duoc dict: gom key (item_id): value: [lan tuong tac cuoi cung ,so luong/thu tu lan tuong tac do]

        if uid in explicit_rating_dict:  # xet trong phan explicit_rating_dict
            for his in explicit_rating_dict[uid]:  # mang cac tuong tac explicit : item_id , time stamp.
                item_id = his[0]
                timestamp = his[1]
                if item_id in explicit_item_time_dict:
                    if timestamp > explicit_item_time_dict[item_id][0]:
                        explicit_item_time_dict[item_id][0] = timestamp
                    explicit_item_time_dict[item_id][1] += 1
                else:
                    explicit_item_time_dict[item_id] = [timestamp, 1]
                # khoi tao dict gom key => mang 2 phan tu [timestamp, stt]
                # => cuoi cung thu duoc dict: gom key (item_id): value: [lan tuong tac cuoi cung ,thu tu lan tuong tac do]

        # write to file
        for i in implicit_item_time_dict:  # moi i trong implicit dict
            if i in explicit_item_time_dict:  # neu no co tuong tac trong ca explicit dict.
                if implicit_item_time_dict[i][0] > explicit_item_time_dict[i][0]:
                    # max timestamp cua item i tren implicit > explicit, gan nguoc time implicit = explicit.
                    implicit_item_time_dict[i][0] = explicit_item_time_dict[i][0]
                csv_writer.writerow([uid, i] + implicit_item_time_dict[i] + explicit_item_time_dict[i])
                # viet ra file ratings.txt:
                # raw_uid,raw_item_id,last_implicit_timestamp,num_implicit,last_explicit_timestamp,num_explicit
            else:  # neu i co implicit ma khong co explicit doi voi user uid
                csv_writer.writerow([uid, i] + implicit_item_time_dict[i] + [-1, 0])
        # doi voi moi j trong explicit
        for j in explicit_item_time_dict:  # neu co explicit ma khong co tuong tac implicit
            if j not in implicit_item_time_dict:  # j chua co trong implicit data
                csv_writer.writerow([uid, j] + explicit_item_time_dict[j] + explicit_item_time_dict[j])
                # raw_uid,raw_item_id,last_explicit_timestamp,num_explicit1,last_explicit_timestamp,num_explicit
    out_file.close()

# %%
cleaned_implicit_data_path = retail_rocket_root_path + '_implicit.clean.txt'
cleaned_explicit_data_path = retail_rocket_root_path + '_explicit.clean.txt'
user_index_dict = retail_rocket_root_path + 'u2index.txt'
item_index_dict = retail_rocket_root_path + 'i2index.txt'
combined_data = retail_rocket_root_path + 'ratings.txt'
gen_ratings_data_with_explicit(cleaned_implicit_data_path, cleaned_explicit_data_path, 
                               user_index_dict, item_index_dict, combined_data)

# %%
import csv
from src import settings

retail_rocket_root_path = settings.DATA_ROOT_PATH + 'site_data/retail_rocket/'
output = retail_rocket_root_path + 'z_temp_ratings.txt'
writefile = open(output, "w")
csv_writer = csv.writer(writefile, delimiter=',', quotechar='', quoting=csv.QUOTE_NONE)

# %%
import csv
from src import settings
retail_rocket_root_path = settings.DATA_ROOT_PATH + 'site_data/retail_rocket/'
file1 = open(retail_rocket_root_path + "ratings_new_ids.txt", "r")
number_explicit = 0
number_line = 0
for line in file1.readlines():
    number_line += 1
    line = line.strip()
    elements = line.split("|")
    interacts = elements[2].strip()[1:-1]
    for interact in interacts.split(","):
        val = interact.strip()
        if int(val) == 1:
            number_explicit +=1
    print ("number line: ", number_line, "number explicit: ", number_explicit)
# Out:
# ('number line: ', 1, 'number explicit: ', 0)
# ('number line: ', 2, 'number explicit: ', 0)
# ('number line: ', 3, 'number explicit: ', 0)
# ('number line: ', 4, 'number explicit: ', 53)
# ('number line: ', 5, 'number explicit: ', 59)
# ('number line: ', 6, 'number explicit: ', 59)
# ('number line: ', 7, 'number explicit: ', 60)
# ('number line: ', 8, 'number explicit: ', 62)
# ('number line: ', 9, 'number explicit: ', 62)
# ('number line: ', 10, 'number explicit: ', 64)
# ('number line: ', 11, 'number explicit: ', 64)
# ('number line: ', 12, 'number explicit: ', 64)
# ('number line: ', 13, 'number explicit: ', 64)
# ('number line: ', 14, 'number explicit: ', 64)
# ('number line: ', 15, 'number explicit: ', 64)
# ('number line: ', 16, 'number explicit: ', 64)
# ('number line: ', 17, 'number explicit: ', 64)
# ('number line: ', 18, 'number explicit: ', 64)
# ('number line: ', 19, 'number explicit: ', 65)
# ('number line: ', 20, 'number explicit: ', 68)
# ('number line: ', 21, 'number explicit: ', 68)
# ('number line: ', 22, 'number explicit: ', 68)
# ('number line: ', 23, 'number explicit: ', 68)
# ('number line: ', 24, 'number explicit: ', 68)
# ('number line: ', 25, 'number explicit: ', 68)
# ('number line: ', 26, 'number explicit: ', 68)
# ('number line: ', 27, 'number explicit: ', 68)
# ('number line: ', 28, 'number explicit: ', 68)
# ('number line: ', 29, 'number explicit: ', 68)
# ('number line: ', 30, 'number explicit: ', 68)
# ('number line: ', 31, 'number explicit: ', 68)
# ('number line: ', 32, 'number explicit: ', 69)
# ('number line: ', 33, 'number explicit: ', 69)
# ('number line: ', 34, 'number explicit: ', 71)
# ('number line: ', 35, 'number explicit: ', 71)
# ('number line: ', 36, 'number explicit: ', 71)
# ('number line: ', 37, 'number explicit: ', 71)
# ('number line: ', 38, 'number explicit: ', 71)
# ('number line: ', 39, 'number explicit: ', 74)
# ('number line: ', 40, 'number explicit: ', 74)
# ('number line: ', 41, 'number explicit: ', 74)
# ('number line: ', 42, 'number explicit: ', 74)
# ('number line: ', 43, 'number explicit: ', 74)
# ('number line: ', 44, 'number explicit: ', 74)
# ('number line: ', 45, 'number explicit: ', 81)
# ('number line: ', 46, 'number explicit: ', 81)
# ('number line: ', 47, 'number explicit: ', 81)
# ('number line: ', 48, 'number explicit: ', 81)
# ('number line: ', 49, 'number explicit: ', 82)
# ('number line: ', 50, 'number explicit: ', 82)
# ('number line: ', 51, 'number explicit: ', 82)
# ('number line: ', 52, 'number explicit: ', 82)
# ('number line: ', 53, 'number explicit: ', 82)
# ('number line: ', 54, 'number explicit: ', 82)
# ('number line: ', 55, 'number explicit: ', 85)
# ('number line: ', 56, 'number explicit: ', 85)
# ('number line: ', 57, 'number explicit: ', 85)
# ('number line: ', 58, 'number explicit: ', 85)
# ('number line: ', 59, 'number explicit: ', 85)
# ('number line: ', 60, 'number explicit: ', 85)
# ('number line: ', 61, 'number explicit: ', 85)
# ('number line: ', 62, 'number explicit: ', 85)
# ('number line: ', 63, 'number explicit: ', 85)
# ('number line: ', 64, 'number explicit: ', 89)
# ('number line: ', 65, 'number explicit: ', 90)
# ('number line: ', 66, 'number explicit: ', 90)
# ('number line: ', 67, 'number explicit: ', 90)
# ('number line: ', 68, 'number explicit: ', 90)
# ('number line: ', 69, 'number explicit: ', 90)
# ('number line: ', 70, 'number explicit: ', 92)
# ('number line: ', 71, 'number explicit: ', 93)
# ('number line: ', 72, 'number explicit: ', 93)
# ('number line: ', 73, 'number explicit: ', 93)
# ('number line: ', 74, 'number explicit: ', 93)
# ('number line: ', 75, 'number explicit: ', 93)
# ('number line: ', 76, 'number explicit: ', 93)
# ('number line: ', 77, 'number explicit: ', 94)
# ('number line: ', 78, 'number explicit: ', 94)
# ('number line: ', 79, 'number explicit: ', 94)
# ('number line: ', 80, 'number explicit: ', 94)
# ('number line: ', 81, 'number explicit: ', 94)
# ('number line: ', 82, 'number explicit: ', 94)
# ('number line: ', 83, 'number explicit: ', 94)
# ('number line: ', 84, 'number explicit: ', 94)
# ('number line: ', 85, 'number explicit: ', 94)
# ('number line: ', 86, 'number explicit: ', 94)
# ('number line: ', 87, 'number explicit: ', 94)
# ('number line: ', 88, 'number explicit: ', 94)
# ('number line: ', 89, 'number explicit: ', 94)
# ('number line: ', 90, 'number explicit: ', 94)
# ('number line: ', 91, 'number explicit: ', 94)
# ('number line: ', 92, 'number explicit: ', 94)
# ('number line: ', 93, 'number explicit: ', 94)
# ('number line: ', 94, 'number explicit: ', 94)
# ('number line: ', 95, 'number explicit: ', 94)
# ('number line: ', 96, 'number explicit: ', 94)
# ('number line: ', 97, 'number explicit: ', 94)
# ('number line: ', 98, 'number explicit: ', 94)
# ('number line: ', 99, 'number explicit: ', 94)
# ('number line: ', 100, 'number explicit: ', 94)
# ('number line: ', 101, 'number explicit: ', 225)
# ('number line: ', 102, 'number explicit: ', 228)
# ('number line: ', 103, 'number explicit: ', 228)
# ('number line: ', 104, 'number explicit: ', 228)
# ('number line: ', 105, 'number explicit: ', 228)
# ('number line: ', 106, 'number explicit: ', 228)
# ('number line: ', 107, 'number explicit: ', 228)
# ('number line: ', 108, 'number explicit: ', 228)
# ('number line: ', 109, 'number explicit: ', 228)
# ('number line: ', 110, 'number explicit: ', 228)
# ('number line: ', 111, 'number explicit: ', 228)
# ('number line: ', 112, 'number explicit: ', 228)
# ('number line: ', 113, 'number explicit: ', 228)
# ('number line: ', 114, 'number explicit: ', 233)
# ('number line: ', 115, 'number explicit: ', 233)
# ('number line: ', 116, 'number explicit: ', 233)
# ('number line: ', 117, 'number explicit: ', 233)
# ('number line: ', 118, 'number explicit: ', 239)
# ('number line: ', 119, 'number explicit: ', 239)
# ('number line: ', 120, 'number explicit: ', 240)
# ('number line: ', 121, 'number explicit: ', 240)
# ('number line: ', 122, 'number explicit: ', 240)
# ('number line: ', 123, 'number explicit: ', 240)
# ('number line: ', 124, 'number explicit: ', 240)
# ('number line: ', 125, 'number explicit: ', 240)
# ('number line: ', 126, 'number explicit: ', 241)
# ('number line: ', 127, 'number explicit: ', 243)
# ('number line: ', 128, 'number explicit: ', 243)
# ('number line: ', 129, 'number explicit: ', 243)
# ('number line: ', 130, 'number explicit: ', 243)
# ('number line: ', 131, 'number explicit: ', 243)
# ('number line: ', 132, 'number explicit: ', 243)
# ('number line: ', 133, 'number explicit: ', 243)
# ('number line: ', 134, 'number explicit: ', 243)
# ('number line: ', 135, 'number explicit: ', 244)
# ('number line: ', 136, 'number explicit: ', 244)
# ('number line: ', 137, 'number explicit: ', 244)
# ('number line: ', 138, 'number explicit: ', 244)
# ('number line: ', 139, 'number explicit: ', 244)
# ('number line: ', 140, 'number explicit: ', 244)
# ('number line: ', 141, 'number explicit: ', 244)
# ('number line: ', 142, 'number explicit: ', 244)
# ('number line: ', 143, 'number explicit: ', 244)
# ('number line: ', 144, 'number explicit: ', 244)
# ('number line: ', 145, 'number explicit: ', 244)
# ('number line: ', 146, 'number explicit: ', 244)
# ('number line: ', 147, 'number explicit: ', 244)
# ('number line: ', 148, 'number explicit: ', 244)
# ('number line: ', 149, 'number explicit: ', 244)
# ('number line: ', 150, 'number explicit: ', 244)
# ('number line: ', 151, 'number explicit: ', 244)
# ('number line: ', 152, 'number explicit: ', 244)
# ('number line: ', 153, 'number explicit: ', 244)
# ('number line: ', 154, 'number explicit: ', 244)
# ('number line: ', 155, 'number explicit: ', 244)
# ('number line: ', 156, 'number explicit: ', 244)
# ('number line: ', 157, 'number explicit: ', 244)
# ('number line: ', 158, 'number explicit: ', 244)
# ('number line: ', 159, 'number explicit: ', 244)
# ('number line: ', 160, 'number explicit: ', 244)
# ('number line: ', 161, 'number explicit: ', 244)
# ('number line: ', 162, 'number explicit: ', 244)
# ('number line: ', 163, 'number explicit: ', 244)
# ('number line: ', 164, 'number explicit: ', 244)
# ('number line: ', 165, 'number explicit: ', 244)
# ('number line: ', 166, 'number explicit: ', 244)
# ('number line: ', 167, 'number explicit: ', 244)
# ('number line: ', 168, 'number explicit: ', 244)
# ('number line: ', 169, 'number explicit: ', 244)
# ('number line: ', 170, 'number explicit: ', 247)
# ('number line: ', 171, 'number explicit: ', 247)
# ('number line: ', 172, 'number explicit: ', 247)
# ('number line: ', 173, 'number explicit: ', 247)
# ('number line: ', 174, 'number explicit: ', 247)
# ('number line: ', 175, 'number explicit: ', 247)
# ('number line: ', 176, 'number explicit: ', 247)
# ('number line: ', 177, 'number explicit: ', 249)
# ('number line: ', 178, 'number explicit: ', 249)
# ('number line: ', 179, 'number explicit: ', 249)
# ('number line: ', 180, 'number explicit: ', 249)
# ('number line: ', 181, 'number explicit: ', 249)
# ('number line: ', 182, 'number explicit: ', 249)
# ('number line: ', 183, 'number explicit: ', 253)
# ('number line: ', 184, 'number explicit: ', 253)
# ('number line: ', 185, 'number explicit: ', 253)
# ('number line: ', 186, 'number explicit: ', 254)
# ('number line: ', 187, 'number explicit: ', 254)
# ('number line: ', 188, 'number explicit: ', 254)
# ('number line: ', 189, 'number explicit: ', 256)
# ('number line: ', 190, 'number explicit: ', 256)
# ('number line: ', 191, 'number explicit: ', 256)
# ('number line: ', 192, 'number explicit: ', 256)
# ('number line: ', 193, 'number explicit: ', 256)
# ('number line: ', 194, 'number explicit: ', 256)
# ('number line: ', 195, 'number explicit: ', 256)
# ('number line: ', 196, 'number explicit: ', 257)
# ('number line: ', 197, 'number explicit: ', 257)
# ('number line: ', 198, 'number explicit: ', 257)
# ('number line: ', 199, 'number explicit: ', 257)
# ('number line: ', 200, 'number explicit: ', 263)
# ('number line: ', 201, 'number explicit: ', 263)
# ('number line: ', 202, 'number explicit: ', 263)
# ('number line: ', 203, 'number explicit: ', 263)
# ('number line: ', 204, 'number explicit: ', 263)
# ('number line: ', 205, 'number explicit: ', 263)
# ('number line: ', 206, 'number explicit: ', 263)
# ('number line: ', 207, 'number explicit: ', 263)
# ('number line: ', 208, 'number explicit: ', 263)
# ('number line: ', 209, 'number explicit: ', 263)
# ('number line: ', 210, 'number explicit: ', 263)
# ('number line: ', 211, 'number explicit: ', 263)
# ('number line: ', 212, 'number explicit: ', 267)
# ('number line: ', 213, 'number explicit: ', 269)
# ('number line: ', 214, 'number explicit: ', 269)
# ('number line: ', 215, 'number explicit: ', 269)
# ('number line: ', 216, 'number explicit: ', 269)
# ('number line: ', 217, 'number explicit: ', 269)
# ('number line: ', 218, 'number explicit: ', 271)
# ('number line: ', 219, 'number explicit: ', 271)
# ('number line: ', 220, 'number explicit: ', 271)
# ('number line: ', 221, 'number explicit: ', 271)
# ('number line: ', 222, 'number explicit: ', 271)
# ('number line: ', 223, 'number explicit: ', 271)
# ('number line: ', 224, 'number explicit: ', 272)
# ('number line: ', 225, 'number explicit: ', 272)
# ('number line: ', 226, 'number explicit: ', 335)
# ('number line: ', 227, 'number explicit: ', 335)
# ('number line: ', 228, 'number explicit: ', 335)
# ('number line: ', 229, 'number explicit: ', 335)
# ('number line: ', 230, 'number explicit: ', 335)
# ('number line: ', 231, 'number explicit: ', 336)
# ('number line: ', 232, 'number explicit: ', 337)
# ('number line: ', 233, 'number explicit: ', 337)
# ('number line: ', 234, 'number explicit: ', 339)
# ('number line: ', 235, 'number explicit: ', 339)
# ('number line: ', 236, 'number explicit: ', 340)
# ('number line: ', 237, 'number explicit: ', 340)
# ('number line: ', 238, 'number explicit: ', 340)
# ('number line: ', 239, 'number explicit: ', 340)
# ('number line: ', 240, 'number explicit: ', 340)
# ('number line: ', 241, 'number explicit: ', 340)
# ('number line: ', 242, 'number explicit: ', 343)
# ('number line: ', 243, 'number explicit: ', 343)
# ('number line: ', 244, 'number explicit: ', 343)
# ('number line: ', 245, 'number explicit: ', 343)
# ('number line: ', 246, 'number explicit: ', 343)
# ('number line: ', 247, 'number explicit: ', 343)
# ('number line: ', 248, 'number explicit: ', 343)
# ('number line: ', 249, 'number explicit: ', 343)
# ('number line: ', 250, 'number explicit: ', 346)
# ('number line: ', 251, 'number explicit: ', 346)
# ('number line: ', 252, 'number explicit: ', 346)
# ('number line: ', 253, 'number explicit: ', 346)
# ('number line: ', 254, 'number explicit: ', 346)
# ('number line: ', 255, 'number explicit: ', 346)
# ('number line: ', 256, 'number explicit: ', 346)
# ('number line: ', 257, 'number explicit: ', 346)
# ('number line: ', 258, 'number explicit: ', 346)
# ('number line: ', 259, 'number explicit: ', 346)
# ('number line: ', 260, 'number explicit: ', 346)
# ('number line: ', 261, 'number explicit: ', 349)
# ('number line: ', 262, 'number explicit: ', 349)
# ('number line: ', 263, 'number explicit: ', 352)
# ('number line: ', 264, 'number explicit: ', 352)
# ('number line: ', 265, 'number explicit: ', 352)
# ('number line: ', 266, 'number explicit: ', 354)
# ('number line: ', 267, 'number explicit: ', 354)
# ('number line: ', 268, 'number explicit: ', 354)
# ('number line: ', 269, 'number explicit: ', 357)
# ('number line: ', 270, 'number explicit: ', 358)
# ('number line: ', 271, 'number explicit: ', 358)
# ('number line: ', 272, 'number explicit: ', 359)
# ('number line: ', 273, 'number explicit: ', 365)
# ('number line: ', 274, 'number explicit: ', 365)
# ('number line: ', 275, 'number explicit: ', 365)
# ('number line: ', 276, 'number explicit: ', 365)
# ('number line: ', 277, 'number explicit: ', 365)
# ('number line: ', 278, 'number explicit: ', 365)
# ('number line: ', 279, 'number explicit: ', 365)
# ('number line: ', 280, 'number explicit: ', 366)
# ('number line: ', 281, 'number explicit: ', 366)
# ('number line: ', 282, 'number explicit: ', 366)
# ('number line: ', 283, 'number explicit: ', 366)
# ('number line: ', 284, 'number explicit: ', 367)
# ('number line: ', 285, 'number explicit: ', 371)
# ('number line: ', 286, 'number explicit: ', 371)
# ('number line: ', 287, 'number explicit: ', 371)
# ('number line: ', 288, 'number explicit: ', 371)
# ('number line: ', 289, 'number explicit: ', 372)
# ('number line: ', 290, 'number explicit: ', 372)
# ('number line: ', 291, 'number explicit: ', 372)
# ('number line: ', 292, 'number explicit: ', 373)
# ('number line: ', 293, 'number explicit: ', 373)
# ('number line: ', 294, 'number explicit: ', 374)
# ('number line: ', 295, 'number explicit: ', 374)
# ('number line: ', 296, 'number explicit: ', 374)
# ('number line: ', 297, 'number explicit: ', 374)
# ('number line: ', 298, 'number explicit: ', 374)
# ('number line: ', 299, 'number explicit: ', 374)
# ('number line: ', 300, 'number explicit: ', 374)
# ('number line: ', 301, 'number explicit: ', 374)
# ('number line: ', 302, 'number explicit: ', 375)
# ('number line: ', 303, 'number explicit: ', 375)
# ('number line: ', 304, 'number explicit: ', 375)
# ('number line: ', 305, 'number explicit: ', 375)
# ('number line: ', 306, 'number explicit: ', 375)
# ('number line: ', 307, 'number explicit: ', 375)
# ('number line: ', 308, 'number explicit: ', 375)
# ('number line: ', 309, 'number explicit: ', 375)
# ('number line: ', 310, 'number explicit: ', 375)
# ('number line: ', 311, 'number explicit: ', 375)
# ('number line: ', 312, 'number explicit: ', 375)
# ('number line: ', 313, 'number explicit: ', 375)
# ('number line: ', 314, 'number explicit: ', 375)
# ('number line: ', 315, 'number explicit: ', 375)
# ('number line: ', 316, 'number explicit: ', 376)
# ('number line: ', 317, 'number explicit: ', 376)
# ('number line: ', 318, 'number explicit: ', 376)
# ('number line: ', 319, 'number explicit: ', 376)
# ('number line: ', 320, 'number explicit: ', 376)
# ('number line: ', 321, 'number explicit: ', 377)
# ('number line: ', 322, 'number explicit: ', 377)
# ('number line: ', 323, 'number explicit: ', 378)
# ('number line: ', 324, 'number explicit: ', 379)
# ('number line: ', 325, 'number explicit: ', 379)
# ('number line: ', 326, 'number explicit: ', 379)
# ('number line: ', 327, 'number explicit: ', 379)
# ('number line: ', 328, 'number explicit: ', 379)
# ('number line: ', 329, 'number explicit: ', 379)
# ('number line: ', 330, 'number explicit: ', 379)
# ('number line: ', 331, 'number explicit: ', 382)
# ('number line: ', 332, 'number explicit: ', 382)
# ('number line: ', 333, 'number explicit: ', 382)
# ('number line: ', 334, 'number explicit: ', 382)
# ('number line: ', 335, 'number explicit: ', 382)
# ('number line: ', 336, 'number explicit: ', 382)
# ('number line: ', 337, 'number explicit: ', 382)
# ('number line: ', 338, 'number explicit: ', 382)
# ('number line: ', 339, 'number explicit: ', 382)
# ('number line: ', 340, 'number explicit: ', 382)
# ('number line: ', 341, 'number explicit: ', 382)
# ('number line: ', 342, 'number explicit: ', 382)
# ('number line: ', 343, 'number explicit: ', 382)
# ('number line: ', 344, 'number explicit: ', 383)
# ('number line: ', 345, 'number explicit: ', 383)
# ('number line: ', 346, 'number explicit: ', 383)
# ('number line: ', 347, 'number explicit: ', 384)
# ('number line: ', 348, 'number explicit: ', 384)
# ('number line: ', 349, 'number explicit: ', 384)
# ('number line: ', 350, 'number explicit: ', 384)
# ('number line: ', 351, 'number explicit: ', 384)
# ('number line: ', 352, 'number explicit: ', 386)
# ('number line: ', 353, 'number explicit: ', 387)
# ('number line: ', 354, 'number explicit: ', 387)
# ('number line: ', 355, 'number explicit: ', 387)
# ('number line: ', 356, 'number explicit: ', 387)
# ('number line: ', 357, 'number explicit: ', 389)
# ('number line: ', 358, 'number explicit: ', 389)
# ('number line: ', 359, 'number explicit: ', 389)
# ('number line: ', 360, 'number explicit: ', 389)
# ('number line: ', 361, 'number explicit: ', 389)
# ('number line: ', 362, 'number explicit: ', 389)
# ('number line: ', 363, 'number explicit: ', 389)
# ('number line: ', 364, 'number explicit: ', 389)
# ('number line: ', 365, 'number explicit: ', 389)
# ('number line: ', 366, 'number explicit: ', 389)
# ('number line: ', 367, 'number explicit: ', 392)
# ('number line: ', 368, 'number explicit: ', 392)
# ('number line: ', 369, 'number explicit: ', 392)
# ('number line: ', 370, 'number explicit: ', 392)
# ('number line: ', 371, 'number explicit: ', 392)
# ('number line: ', 372, 'number explicit: ', 392)
# ('number line: ', 373, 'number explicit: ', 392)
# ('number line: ', 374, 'number explicit: ', 400)
# ('number line: ', 375, 'number explicit: ', 400)
# ('number line: ', 376, 'number explicit: ', 400)
# ('number line: ', 377, 'number explicit: ', 400)
# ('number line: ', 378, 'number explicit: ', 400)
# ('number line: ', 379, 'number explicit: ', 400)
# ('number line: ', 380, 'number explicit: ', 400)
# ('number line: ', 381, 'number explicit: ', 400)
# ('number line: ', 382, 'number explicit: ', 400)
# ('number line: ', 383, 'number explicit: ', 400)
# ('number line: ', 384, 'number explicit: ', 400)
# ('number line: ', 385, 'number explicit: ', 400)
# ('number line: ', 386, 'number explicit: ', 400)
# ('number line: ', 387, 'number explicit: ', 400)
# ('number line: ', 388, 'number explicit: ', 400)
# ('number line: ', 389, 'number explicit: ', 400)
# ('number line: ', 390, 'number explicit: ', 400)
# ('number line: ', 391, 'number explicit: ', 400)
# ('number line: ', 392, 'number explicit: ', 401)
# ('number line: ', 393, 'number explicit: ', 431)
# ('number line: ', 394, 'number explicit: ', 431)
# ('number line: ', 395, 'number explicit: ', 431)
# ('number line: ', 396, 'number explicit: ', 431)
# ('number line: ', 397, 'number explicit: ', 434)
# ('number line: ', 398, 'number explicit: ', 434)
# ('number line: ', 399, 'number explicit: ', 436)
# ('number line: ', 400, 'number explicit: ', 436)
# ('number line: ', 401, 'number explicit: ', 436)
# ('number line: ', 402, 'number explicit: ', 436)
# ('number line: ', 403, 'number explicit: ', 458)
# ('number line: ', 404, 'number explicit: ', 458)
# ('number line: ', 405, 'number explicit: ', 458)
# ('number line: ', 406, 'number explicit: ', 458)
# ('number line: ', 407, 'number explicit: ', 458)
# ('number line: ', 408, 'number explicit: ', 458)
# ('number line: ', 409, 'number explicit: ', 458)
# ('number line: ', 410, 'number explicit: ', 458)
# ('number line: ', 411, 'number explicit: ', 458)
# ('number line: ', 412, 'number explicit: ', 458)
# ('number line: ', 413, 'number explicit: ', 458)
# ('number line: ', 414, 'number explicit: ', 458)
# ('number line: ', 415, 'number explicit: ', 458)
# ('number line: ', 416, 'number explicit: ', 458)
# ('number line: ', 417, 'number explicit: ', 458)
# ('number line: ', 418, 'number explicit: ', 458)
# ('number line: ', 419, 'number explicit: ', 458)
# ('number line: ', 420, 'number explicit: ', 458)
# ('number line: ', 421, 'number explicit: ', 458)
# ('number line: ', 422, 'number explicit: ', 459)
# ('number line: ', 423, 'number explicit: ', 459)
# ('number line: ', 424, 'number explicit: ', 459)
# ('number line: ', 425, 'number explicit: ', 459)
# ('number line: ', 426, 'number explicit: ', 459)
# ('number line: ', 427, 'number explicit: ', 459)
# ('number line: ', 428, 'number explicit: ', 459)
# ('number line: ', 429, 'number explicit: ', 460)
# ('number line: ', 430, 'number explicit: ', 460)
# ('number line: ', 431, 'number explicit: ', 460)
# ('number line: ', 432, 'number explicit: ', 463)
# ('number line: ', 433, 'number explicit: ', 463)
# ('number line: ', 434, 'number explicit: ', 463)
# ('number line: ', 435, 'number explicit: ', 463)
# ('number line: ', 436, 'number explicit: ', 463)
# ('number line: ', 437, 'number explicit: ', 463)
# ('number line: ', 438, 'number explicit: ', 463)
# ('number line: ', 439, 'number explicit: ', 463)
# ('number line: ', 440, 'number explicit: ', 463)
# ('number line: ', 441, 'number explicit: ', 463)
# ('number line: ', 442, 'number explicit: ', 463)
# ('number line: ', 443, 'number explicit: ', 463)
# ('number line: ', 444, 'number explicit: ', 463)
# ('number line: ', 445, 'number explicit: ', 463)
# ('number line: ', 446, 'number explicit: ', 463)
# ('number line: ', 447, 'number explicit: ', 463)
# ('number line: ', 448, 'number explicit: ', 463)
# ('number line: ', 449, 'number explicit: ', 472)
# ('number line: ', 450, 'number explicit: ', 472)
# ('number line: ', 451, 'number explicit: ', 472)
# ('number line: ', 452, 'number explicit: ', 473)
# ('number line: ', 453, 'number explicit: ', 474)
# ('number line: ', 454, 'number explicit: ', 474)
# ('number line: ', 455, 'number explicit: ', 474)
# ('number line: ', 456, 'number explicit: ', 474)
# ('number line: ', 457, 'number explicit: ', 474)
# ('number line: ', 458, 'number explicit: ', 474)
# ('number line: ', 459, 'number explicit: ', 474)
# ('number line: ', 460, 'number explicit: ', 474)
# ('number line: ', 461, 'number explicit: ', 474)
# ('number line: ', 462, 'number explicit: ', 475)
# ('number line: ', 463, 'number explicit: ', 475)
# ('number line: ', 464, 'number explicit: ', 475)
# ('number line: ', 465, 'number explicit: ', 475)
# ('number line: ', 466, 'number explicit: ', 486)
# ('number line: ', 467, 'number explicit: ', 486)
# ('number line: ', 468, 'number explicit: ', 488)
# ('number line: ', 469, 'number explicit: ', 488)
# ('number line: ', 470, 'number explicit: ', 488)
# ('number line: ', 471, 'number explicit: ', 488)
# ('number line: ', 472, 'number explicit: ', 488)
# ('number line: ', 473, 'number explicit: ', 488)
# ('number line: ', 474, 'number explicit: ', 488)
# ('number line: ', 475, 'number explicit: ', 488)
# ('number line: ', 476, 'number explicit: ', 488)
# ('number line: ', 477, 'number explicit: ', 488)
# ('number line: ', 478, 'number explicit: ', 488)
# ('number line: ', 479, 'number explicit: ', 488)
# ('number line: ', 480, 'number explicit: ', 488)
# ('number line: ', 481, 'number explicit: ', 488)
# ('number line: ', 482, 'number explicit: ', 488)
# ('number line: ', 483, 'number explicit: ', 488)
# ('number line: ', 484, 'number explicit: ', 488)
# ('number line: ', 485, 'number explicit: ', 488)
# ('number line: ', 486, 'number explicit: ', 489)
# ('number line: ', 487, 'number explicit: ', 489)
# ('number line: ', 488, 'number explicit: ', 489)
# ('number line: ', 489, 'number explicit: ', 489)
# ('number line: ', 490, 'number explicit: ', 489)
# ('number line: ', 491, 'number explicit: ', 489)
# ('number line: ', 492, 'number explicit: ', 489)
# ('number line: ', 493, 'number explicit: ', 489)
# ('number line: ', 494, 'number explicit: ', 489)
# ('number line: ', 495, 'number explicit: ', 489)
# ('number line: ', 496, 'number explicit: ', 489)
# ('number line: ', 497, 'number explicit: ', 490)
# ('number line: ', 498, 'number explicit: ', 491)
# ('number line: ', 499, 'number explicit: ', 493)
# ('number line: ', 500, 'number explicit: ', 493)
# ('number line: ', 501, 'number explicit: ', 493)
# ('number line: ', 502, 'number explicit: ', 493)
# ('number line: ', 503, 'number explicit: ', 493)
# ('number line: ', 504, 'number explicit: ', 496)
# ('number line: ', 505, 'number explicit: ', 496)
# ('number line: ', 506, 'number explicit: ', 496)
# ('number line: ', 507, 'number explicit: ', 496)
# ('number line: ', 508, 'number explicit: ', 496)
# ('number line: ', 509, 'number explicit: ', 497)
# ('number line: ', 510, 'number explicit: ', 497)
# ('number line: ', 511, 'number explicit: ', 497)
# ('number line: ', 512, 'number explicit: ', 497)
# ('number line: ', 513, 'number explicit: ', 497)
# ('number line: ', 514, 'number explicit: ', 497)
# ('number line: ', 515, 'number explicit: ', 497)
# ('number line: ', 516, 'number explicit: ', 497)
# ('number line: ', 517, 'number explicit: ', 497)
# ('number line: ', 518, 'number explicit: ', 498)
# ('number line: ', 519, 'number explicit: ', 498)
# ('number line: ', 520, 'number explicit: ', 498)
# ('number line: ', 521, 'number explicit: ', 502)
# ('number line: ', 522, 'number explicit: ', 507)
# ('number line: ', 523, 'number explicit: ', 507)
# ('number line: ', 524, 'number explicit: ', 511)
# ('number line: ', 525, 'number explicit: ', 511)
# ('number line: ', 526, 'number explicit: ', 511)
# ('number line: ', 527, 'number explicit: ', 511)
# ('number line: ', 528, 'number explicit: ', 511)
# ('number line: ', 529, 'number explicit: ', 511)
# ('number line: ', 530, 'number explicit: ', 511)
# ('number line: ', 531, 'number explicit: ', 511)
# ('number line: ', 532, 'number explicit: ', 511)
# ('number line: ', 533, 'number explicit: ', 511)
# ('number line: ', 534, 'number explicit: ', 511)
# ('number line: ', 535, 'number explicit: ', 511)
# ('number line: ', 536, 'number explicit: ', 511)
# ('number line: ', 537, 'number explicit: ', 513)
# ('number line: ', 538, 'number explicit: ', 513)
# ('number line: ', 539, 'number explicit: ', 513)
# ('number line: ', 540, 'number explicit: ', 513)
# ('number line: ', 541, 'number explicit: ', 513)
# ('number line: ', 542, 'number explicit: ', 513)
# ('number line: ', 543, 'number explicit: ', 513)
# ('number line: ', 544, 'number explicit: ', 516)
# ('number line: ', 545, 'number explicit: ', 516)
# ('number line: ', 546, 'number explicit: ', 516)
# ('number line: ', 547, 'number explicit: ', 516)
# ('number line: ', 548, 'number explicit: ', 516)
# ('number line: ', 549, 'number explicit: ', 516)
# ('number line: ', 550, 'number explicit: ', 520)
# ('number line: ', 551, 'number explicit: ', 520)
# ('number line: ', 552, 'number explicit: ', 520)
# ('number line: ', 553, 'number explicit: ', 520)
# ('number line: ', 554, 'number explicit: ', 522)
# ('number line: ', 555, 'number explicit: ', 523)
# ('number line: ', 556, 'number explicit: ', 523)
# ('number line: ', 557, 'number explicit: ', 523)
# ('number line: ', 558, 'number explicit: ', 524)
# ('number line: ', 559, 'number explicit: ', 524)
# ('number line: ', 560, 'number explicit: ', 524)
# ('number line: ', 561, 'number explicit: ', 524)
# ('number line: ', 562, 'number explicit: ', 524)
# ('number line: ', 563, 'number explicit: ', 524)
# ('number line: ', 564, 'number explicit: ', 524)
# ('number line: ', 565, 'number explicit: ', 524)
# ('number line: ', 566, 'number explicit: ', 524)
# ('number line: ', 567, 'number explicit: ', 524)
# ('number line: ', 568, 'number explicit: ', 524)
# ('number line: ', 569, 'number explicit: ', 524)
# ('number line: ', 570, 'number explicit: ', 525)
# ('number line: ', 571, 'number explicit: ', 525)
# ('number line: ', 572, 'number explicit: ', 525)
# ('number line: ', 573, 'number explicit: ', 525)
# ('number line: ', 574, 'number explicit: ', 525)
# ('number line: ', 575, 'number explicit: ', 527)
# ('number line: ', 576, 'number explicit: ', 527)
# ('number line: ', 577, 'number explicit: ', 527)
# ('number line: ', 578, 'number explicit: ', 527)
# ('number line: ', 579, 'number explicit: ', 527)
# ('number line: ', 580, 'number explicit: ', 527)
# ('number line: ', 581, 'number explicit: ', 527)
# ('number line: ', 582, 'number explicit: ', 527)
# ('number line: ', 583, 'number explicit: ', 527)
# ('number line: ', 584, 'number explicit: ', 527)
# ('number line: ', 585, 'number explicit: ', 527)
# ('number line: ', 586, 'number explicit: ', 527)
# ('number line: ', 587, 'number explicit: ', 542)
# ('number line: ', 588, 'number explicit: ', 542)
# ('number line: ', 589, 'number explicit: ', 542)
# ('number line: ', 590, 'number explicit: ', 542)
# ('number line: ', 591, 'number explicit: ', 550)
# ('number line: ', 592, 'number explicit: ', 550)
# ('number line: ', 593, 'number explicit: ', 550)
# ('number line: ', 594, 'number explicit: ', 550)
# ('number line: ', 595, 'number explicit: ', 550)
# ('number line: ', 596, 'number explicit: ', 550)
# ('number line: ', 597, 'number explicit: ', 550)
# ('number line: ', 598, 'number explicit: ', 568)
# ('number line: ', 599, 'number explicit: ', 568)
# ('number line: ', 600, 'number explicit: ', 568)
# ('number line: ', 601, 'number explicit: ', 568)
# ('number line: ', 602, 'number explicit: ', 568)
# ('number line: ', 603, 'number explicit: ', 568)
# ('number line: ', 604, 'number explicit: ', 568)
# ('number line: ', 605, 'number explicit: ', 568)
# ('number line: ', 606, 'number explicit: ', 568)
# ('number line: ', 607, 'number explicit: ', 568)
# ('number line: ', 608, 'number explicit: ', 568)
# ('number line: ', 609, 'number explicit: ', 569)
# ('number line: ', 610, 'number explicit: ', 569)
# ('number line: ', 611, 'number explicit: ', 574)
# ('number line: ', 612, 'number explicit: ', 591)
# ('number line: ', 613, 'number explicit: ', 591)
# ('number line: ', 614, 'number explicit: ', 591)
# ('number line: ', 615, 'number explicit: ', 591)
# ('number line: ', 616, 'number explicit: ', 591)
# ('number line: ', 617, 'number explicit: ', 591)
# ('number line: ', 618, 'number explicit: ', 594)
# ('number line: ', 619, 'number explicit: ', 594)
# ('number line: ', 620, 'number explicit: ', 599)
# ('number line: ', 621, 'number explicit: ', 599)
# ('number line: ', 622, 'number explicit: ', 599)
# ('number line: ', 623, 'number explicit: ', 599)
# ('number line: ', 624, 'number explicit: ', 599)
# ('number line: ', 625, 'number explicit: ', 599)
# ('number line: ', 626, 'number explicit: ', 599)
# ('number line: ', 627, 'number explicit: ', 599)
# ('number line: ', 628, 'number explicit: ', 599)
# ('number line: ', 629, 'number explicit: ', 599)
# ('number line: ', 630, 'number explicit: ', 599)
# ('number line: ', 631, 'number explicit: ', 599)
# ('number line: ', 632, 'number explicit: ', 599)
# ('number line: ', 633, 'number explicit: ', 599)
# ('number line: ', 634, 'number explicit: ', 599)
# ('number line: ', 635, 'number explicit: ', 601)
# ('number line: ', 636, 'number explicit: ', 601)
# ('number line: ', 637, 'number explicit: ', 601)
# ('number line: ', 638, 'number explicit: ', 603)
# ('number line: ', 639, 'number explicit: ', 603)
# ('number line: ', 640, 'number explicit: ', 603)
# ('number line: ', 641, 'number explicit: ', 603)
# ('number line: ', 642, 'number explicit: ', 603)
# ('number line: ', 643, 'number explicit: ', 603)
# ('number line: ', 644, 'number explicit: ', 603)
# ('number line: ', 645, 'number explicit: ', 612)
# ('number line: ', 646, 'number explicit: ', 612)
# ('number line: ', 647, 'number explicit: ', 613)
# ('number line: ', 648, 'number explicit: ', 613)
# ('number line: ', 649, 'number explicit: ', 613)
# ('number line: ', 650, 'number explicit: ', 622)
# ('number line: ', 651, 'number explicit: ', 622)
# ('number line: ', 652, 'number explicit: ', 622)
# ('number line: ', 653, 'number explicit: ', 622)
# ('number line: ', 654, 'number explicit: ', 622)
# ('number line: ', 655, 'number explicit: ', 622)
# ('number line: ', 656, 'number explicit: ', 623)
# ('number line: ', 657, 'number explicit: ', 623)
# ('number line: ', 658, 'number explicit: ', 623)
# ('number line: ', 659, 'number explicit: ', 623)
# ('number line: ', 660, 'number explicit: ', 623)
# ('number line: ', 661, 'number explicit: ', 626)
# ('number line: ', 662, 'number explicit: ', 626)
# ('number line: ', 663, 'number explicit: ', 626)
# ('number line: ', 664, 'number explicit: ', 626)
# ('number line: ', 665, 'number explicit: ', 626)
# ('number line: ', 666, 'number explicit: ', 626)
# ('number line: ', 667, 'number explicit: ', 626)
# ('number line: ', 668, 'number explicit: ', 631)
# ('number line: ', 669, 'number explicit: ', 631)
# ('number line: ', 670, 'number explicit: ', 631)
# ('number line: ', 671, 'number explicit: ', 631)
# ('number line: ', 672, 'number explicit: ', 631)
# ('number line: ', 673, 'number explicit: ', 631)
# ('number line: ', 674, 'number explicit: ', 631)
# ('number line: ', 675, 'number explicit: ', 631)
# ('number line: ', 676, 'number explicit: ', 632)
# ('number line: ', 677, 'number explicit: ', 632)
# ('number line: ', 678, 'number explicit: ', 632)
# ('number line: ', 679, 'number explicit: ', 632)
# ('number line: ', 680, 'number explicit: ', 632)
# ('number line: ', 681, 'number explicit: ', 633)
# ('number line: ', 682, 'number explicit: ', 633)
# ('number line: ', 683, 'number explicit: ', 633)
# ('number line: ', 684, 'number explicit: ', 633)
# ('number line: ', 685, 'number explicit: ', 633)
# ('number line: ', 686, 'number explicit: ', 633)
# ('number line: ', 687, 'number explicit: ', 633)
# ('number line: ', 688, 'number explicit: ', 633)
# ('number line: ', 689, 'number explicit: ', 633)
# ('number line: ', 690, 'number explicit: ', 633)
# ('number line: ', 691, 'number explicit: ', 636)
# ('number line: ', 692, 'number explicit: ', 636)
# ('number line: ', 693, 'number explicit: ', 636)
# ('number line: ', 694, 'number explicit: ', 636)
# ('number line: ', 695, 'number explicit: ', 637)
# ('number line: ', 696, 'number explicit: ', 637)
# ('number line: ', 697, 'number explicit: ', 637)
# ('number line: ', 698, 'number explicit: ', 637)
# ('number line: ', 699, 'number explicit: ', 637)
# ('number line: ', 700, 'number explicit: ', 639)
# ('number line: ', 701, 'number explicit: ', 639)
# ('number line: ', 702, 'number explicit: ', 644)
# ('number line: ', 703, 'number explicit: ', 646)
# ('number line: ', 704, 'number explicit: ', 646)
# ('number line: ', 705, 'number explicit: ', 646)
# ('number line: ', 706, 'number explicit: ', 646)
# ('number line: ', 707, 'number explicit: ', 646)
# ('number line: ', 708, 'number explicit: ', 646)
# ('number line: ', 709, 'number explicit: ', 646)
# ('number line: ', 710, 'number explicit: ', 646)
# ('number line: ', 711, 'number explicit: ', 646)
# ('number line: ', 712, 'number explicit: ', 646)
# ('number line: ', 713, 'number explicit: ', 646)
# ('number line: ', 714, 'number explicit: ', 650)
# ('number line: ', 715, 'number explicit: ', 650)
# ('number line: ', 716, 'number explicit: ', 650)
# ('number line: ', 717, 'number explicit: ', 658)
# ('number line: ', 718, 'number explicit: ', 658)
# ('number line: ', 719, 'number explicit: ', 658)
# ('number line: ', 720, 'number explicit: ', 658)
# ('number line: ', 721, 'number explicit: ', 658)
# ('number line: ', 722, 'number explicit: ', 661)
# ('number line: ', 723, 'number explicit: ', 661)
# ('number line: ', 724, 'number explicit: ', 661)
# ('number line: ', 725, 'number explicit: ', 661)
# ('number line: ', 726, 'number explicit: ', 661)
# ('number line: ', 727, 'number explicit: ', 662)
# ('number line: ', 728, 'number explicit: ', 662)
# ('number line: ', 729, 'number explicit: ', 662)
# ('number line: ', 730, 'number explicit: ', 662)
# ('number line: ', 731, 'number explicit: ', 662)
# ('number line: ', 732, 'number explicit: ', 676)
# ('number line: ', 733, 'number explicit: ', 676)
# ('number line: ', 734, 'number explicit: ', 676)
# ('number line: ', 735, 'number explicit: ', 680)
# ('number line: ', 736, 'number explicit: ', 681)
# ('number line: ', 737, 'number explicit: ', 681)
# ('number line: ', 738, 'number explicit: ', 681)
# ('number line: ', 739, 'number explicit: ', 681)
# ('number line: ', 740, 'number explicit: ', 681)
# ('number line: ', 741, 'number explicit: ', 681)
# ('number line: ', 742, 'number explicit: ', 681)
# ('number line: ', 743, 'number explicit: ', 683)
# ('number line: ', 744, 'number explicit: ', 683)
# ('number line: ', 745, 'number explicit: ', 683)
# ('number line: ', 746, 'number explicit: ', 684)
# ('number line: ', 747, 'number explicit: ', 684)
# ('number line: ', 748, 'number explicit: ', 684)
# ('number line: ', 749, 'number explicit: ', 684)
# ('number line: ', 750, 'number explicit: ', 685)
# ('number line: ', 751, 'number explicit: ', 685)
# ('number line: ', 752, 'number explicit: ', 685)
# ('number line: ', 753, 'number explicit: ', 685)
# ('number line: ', 754, 'number explicit: ', 686)
# ('number line: ', 755, 'number explicit: ', 686)
# ('number line: ', 756, 'number explicit: ', 691)
# ('number line: ', 757, 'number explicit: ', 691)
# ('number line: ', 758, 'number explicit: ', 691)
# ('number line: ', 759, 'number explicit: ', 691)
# ('number line: ', 760, 'number explicit: ', 691)
# ('number line: ', 761, 'number explicit: ', 691)
# ('number line: ', 762, 'number explicit: ', 691)
# ('number line: ', 763, 'number explicit: ', 691)
# ('number line: ', 764, 'number explicit: ', 691)
# ('number line: ', 765, 'number explicit: ', 691)
# ('number line: ', 766, 'number explicit: ', 691)
# ('number line: ', 767, 'number explicit: ', 691)
# ('number line: ', 768, 'number explicit: ', 700)
# ('number line: ', 769, 'number explicit: ', 700)
# ('number line: ', 770, 'number explicit: ', 700)
# ('number line: ', 771, 'number explicit: ', 702)
# ('number line: ', 772, 'number explicit: ', 702)
# ('number line: ', 773, 'number explicit: ', 703)
# ('number line: ', 774, 'number explicit: ', 703)
# ('number line: ', 775, 'number explicit: ', 703)
# ('number line: ', 776, 'number explicit: ', 707)
# ('number line: ', 777, 'number explicit: ', 708)
# ('number line: ', 778, 'number explicit: ', 708)
# ('number line: ', 779, 'number explicit: ', 708)
# ('number line: ', 780, 'number explicit: ', 708)
# ('number line: ', 781, 'number explicit: ', 708)
# ('number line: ', 782, 'number explicit: ', 711)
# ('number line: ', 783, 'number explicit: ', 712)
# ('number line: ', 784, 'number explicit: ', 712)
# ('number line: ', 785, 'number explicit: ', 713)
# ('number line: ', 786, 'number explicit: ', 713)
# ('number line: ', 787, 'number explicit: ', 713)
# ('number line: ', 788, 'number explicit: ', 713)
# ('number line: ', 789, 'number explicit: ', 714)
# ('number line: ', 790, 'number explicit: ', 714)
# ('number line: ', 791, 'number explicit: ', 715)
# ('number line: ', 792, 'number explicit: ', 717)
# ('number line: ', 793, 'number explicit: ', 717)
# ('number line: ', 794, 'number explicit: ', 717)
# ('number line: ', 795, 'number explicit: ', 717)
# ('number line: ', 796, 'number explicit: ', 717)
# ('number line: ', 797, 'number explicit: ', 717)
# ('number line: ', 798, 'number explicit: ', 717)
# ('number line: ', 799, 'number explicit: ', 719)
# ('number line: ', 800, 'number explicit: ', 719)
# ('number line: ', 801, 'number explicit: ', 719)
# ('number line: ', 802, 'number explicit: ', 719)
# ('number line: ', 803, 'number explicit: ', 719)
# ('number line: ', 804, 'number explicit: ', 719)
# ('number line: ', 805, 'number explicit: ', 719)
# ('number line: ', 806, 'number explicit: ', 719)
# ('number line: ', 807, 'number explicit: ', 719)
# ('number line: ', 808, 'number explicit: ', 720)
# ('number line: ', 809, 'number explicit: ', 720)
# ('number line: ', 810, 'number explicit: ', 720)
# ('number line: ', 811, 'number explicit: ', 720)
# ('number line: ', 812, 'number explicit: ', 720)
# ('number line: ', 813, 'number explicit: ', 720)
# ('number line: ', 814, 'number explicit: ', 720)
# ('number line: ', 815, 'number explicit: ', 724)
# ('number line: ', 816, 'number explicit: ', 724)
# ('number line: ', 817, 'number explicit: ', 724)
# ('number line: ', 818, 'number explicit: ', 724)
# ('number line: ', 819, 'number explicit: ', 724)
# ('number line: ', 820, 'number explicit: ', 724)
# ('number line: ', 821, 'number explicit: ', 724)
# ('number line: ', 822, 'number explicit: ', 724)
# ('number line: ', 823, 'number explicit: ', 724)
# ('number line: ', 824, 'number explicit: ', 724)
# ('number line: ', 825, 'number explicit: ', 727)
# ('number line: ', 826, 'number explicit: ', 727)
# ('number line: ', 827, 'number explicit: ', 727)
# ('number line: ', 828, 'number explicit: ', 727)
# ('number line: ', 829, 'number explicit: ', 727)
# ('number line: ', 830, 'number explicit: ', 727)
# ('number line: ', 831, 'number explicit: ', 727)
# ('number line: ', 832, 'number explicit: ', 729)
# ('number line: ', 833, 'number explicit: ', 729)
# ('number line: ', 834, 'number explicit: ', 729)
# ('number line: ', 835, 'number explicit: ', 729)
# ('number line: ', 836, 'number explicit: ', 729)
# ('number line: ', 837, 'number explicit: ', 729)
# ('number line: ', 838, 'number explicit: ', 729)
# ('number line: ', 839, 'number explicit: ', 730)
# ('number line: ', 840, 'number explicit: ', 730)
# ('number line: ', 841, 'number explicit: ', 730)
# ('number line: ', 842, 'number explicit: ', 730)
# ('number line: ', 843, 'number explicit: ', 730)
# ('number line: ', 844, 'number explicit: ', 730)
# ('number line: ', 845, 'number explicit: ', 731)
# ('number line: ', 846, 'number explicit: ', 731)
# ('number line: ', 847, 'number explicit: ', 733)
# ('number line: ', 848, 'number explicit: ', 733)
# ('number line: ', 849, 'number explicit: ', 733)
# ('number line: ', 850, 'number explicit: ', 733)
# ('number line: ', 851, 'number explicit: ', 733)
# ('number line: ', 852, 'number explicit: ', 733)
# ('number line: ', 853, 'number explicit: ', 733)
# ('number line: ', 854, 'number explicit: ', 733)
# ('number line: ', 855, 'number explicit: ', 733)
# ('number line: ', 856, 'number explicit: ', 733)
# ('number line: ', 857, 'number explicit: ', 741)
# ('number line: ', 858, 'number explicit: ', 741)
# ('number line: ', 859, 'number explicit: ', 741)
# ('number line: ', 860, 'number explicit: ', 741)
# ('number line: ', 861, 'number explicit: ', 741)
# ('number line: ', 862, 'number explicit: ', 741)
# ('number line: ', 863, 'number explicit: ', 741)
# ('number line: ', 864, 'number explicit: ', 741)
# ('number line: ', 865, 'number explicit: ', 741)
# ('number line: ', 866, 'number explicit: ', 741)
# ('number line: ', 867, 'number explicit: ', 741)
# ('number line: ', 868, 'number explicit: ', 741)
# ('number line: ', 869, 'number explicit: ', 741)
# ('number line: ', 870, 'number explicit: ', 741)
# ('number line: ', 871, 'number explicit: ', 746)
# ('number line: ', 872, 'number explicit: ', 746)
# ('number line: ', 873, 'number explicit: ', 746)
# ('number line: ', 874, 'number explicit: ', 746)
# ('number line: ', 875, 'number explicit: ', 746)
# ('number line: ', 876, 'number explicit: ', 746)
# ('number line: ', 877, 'number explicit: ', 746)
# ('number line: ', 878, 'number explicit: ', 746)
# ('number line: ', 879, 'number explicit: ', 746)
# ('number line: ', 880, 'number explicit: ', 746)
# ('number line: ', 881, 'number explicit: ', 746)
# ('number line: ', 882, 'number explicit: ', 746)
# ('number line: ', 883, 'number explicit: ', 746)
# ('number line: ', 884, 'number explicit: ', 746)
# ('number line: ', 885, 'number explicit: ', 746)
# ('number line: ', 886, 'number explicit: ', 746)
# ('number line: ', 887, 'number explicit: ', 746)
# ('number line: ', 888, 'number explicit: ', 746)
# ('number line: ', 889, 'number explicit: ', 754)
# ('number line: ', 890, 'number explicit: ', 754)
# ('number line: ', 891, 'number explicit: ', 758)
# ('number line: ', 892, 'number explicit: ', 758)
# ('number line: ', 893, 'number explicit: ', 759)
# ('number line: ', 894, 'number explicit: ', 759)
# ('number line: ', 895, 'number explicit: ', 759)
# ('number line: ', 896, 'number explicit: ', 759)
# ('number line: ', 897, 'number explicit: ', 759)
# ('number line: ', 898, 'number explicit: ', 759)
# ('number line: ', 899, 'number explicit: ', 759)
# ('number line: ', 900, 'number explicit: ', 759)
# ('number line: ', 901, 'number explicit: ', 760)
# ('number line: ', 902, 'number explicit: ', 760)
# ('number line: ', 903, 'number explicit: ', 760)
# ('number line: ', 904, 'number explicit: ', 761)
# ('number line: ', 905, 'number explicit: ', 763)
# ('number line: ', 906, 'number explicit: ', 763)
# ('number line: ', 907, 'number explicit: ', 763)
# ('number line: ', 908, 'number explicit: ', 763)
# ('number line: ', 909, 'number explicit: ', 763)
# ('number line: ', 910, 'number explicit: ', 763)
# ('number line: ', 911, 'number explicit: ', 763)
# ('number line: ', 912, 'number explicit: ', 763)
# ('number line: ', 913, 'number explicit: ', 791)
# ('number line: ', 914, 'number explicit: ', 791)
# ('number line: ', 915, 'number explicit: ', 791)
# ('number line: ', 916, 'number explicit: ', 791)
# ('number line: ', 917, 'number explicit: ', 791)
# ('number line: ', 918, 'number explicit: ', 791)
# ('number line: ', 919, 'number explicit: ', 793)
# ('number line: ', 920, 'number explicit: ', 803)
# ('number line: ', 921, 'number explicit: ', 803)
# ('number line: ', 922, 'number explicit: ', 803)
# ('number line: ', 923, 'number explicit: ', 803)
# ('number line: ', 924, 'number explicit: ', 810)
# ('number line: ', 925, 'number explicit: ', 810)
# ('number line: ', 926, 'number explicit: ', 810)
# ('number line: ', 927, 'number explicit: ', 811)
# ('number line: ', 928, 'number explicit: ', 811)
# ('number line: ', 929, 'number explicit: ', 811)
# ('number line: ', 930, 'number explicit: ', 811)
# ('number line: ', 931, 'number explicit: ', 826)
# ('number line: ', 932, 'number explicit: ', 826)
# ('number line: ', 933, 'number explicit: ', 828)
# ('number line: ', 934, 'number explicit: ', 828)
# ('number line: ', 935, 'number explicit: ', 828)
# ('number line: ', 936, 'number explicit: ', 828)
# ('number line: ', 937, 'number explicit: ', 828)
# ('number line: ', 938, 'number explicit: ', 831)
# ('number line: ', 939, 'number explicit: ', 831)
# ('number line: ', 940, 'number explicit: ', 831)
# ('number line: ', 941, 'number explicit: ', 831)
# ('number line: ', 942, 'number explicit: ', 831)
# ('number line: ', 943, 'number explicit: ', 831)
# ('number line: ', 944, 'number explicit: ', 831)
# ('number line: ', 945, 'number explicit: ', 831)
# ('number line: ', 946, 'number explicit: ', 831)
# ('number line: ', 947, 'number explicit: ', 831)
# ('number line: ', 948, 'number explicit: ', 831)
# ('number line: ', 949, 'number explicit: ', 831)
# ('number line: ', 950, 'number explicit: ', 831)
# ('number line: ', 951, 'number explicit: ', 831)
# ('number line: ', 952, 'number explicit: ', 831)
# ('number line: ', 953, 'number explicit: ', 831)
# ('number line: ', 954, 'number explicit: ', 831)
# ('number line: ', 955, 'number explicit: ', 831)
# ('number line: ', 956, 'number explicit: ', 831)
# ('number line: ', 957, 'number explicit: ', 831)
# ('number line: ', 958, 'number explicit: ', 831)
# ('number line: ', 959, 'number explicit: ', 831)
# ('number line: ', 960, 'number explicit: ', 831)
# ('number line: ', 961, 'number explicit: ', 831)
# ('number line: ', 962, 'number explicit: ', 831)
# ('number line: ', 963, 'number explicit: ', 831)
# ('number line: ', 964, 'number explicit: ', 834)
# ('number line: ', 965, 'number explicit: ', 834)
# ('number line: ', 966, 'number explicit: ', 834)
# ('number line: ', 967, 'number explicit: ', 834)
# ('number line: ', 968, 'number explicit: ', 836)
# ('number line: ', 969, 'number explicit: ', 836)
# ('number line: ', 970, 'number explicit: ', 836)
# ('number line: ', 971, 'number explicit: ', 836)
# ('number line: ', 972, 'number explicit: ', 836)
# ('number line: ', 973, 'number explicit: ', 836)
# ('number line: ', 974, 'number explicit: ', 836)
# ('number line: ', 975, 'number explicit: ', 839)
# ('number line: ', 976, 'number explicit: ', 839)
# ('number line: ', 977, 'number explicit: ', 839)
# ('number line: ', 978, 'number explicit: ', 843)
# ('number line: ', 979, 'number explicit: ', 843)
# ('number line: ', 980, 'number explicit: ', 843)
# ('number line: ', 981, 'number explicit: ', 843)
# ('number line: ', 982, 'number explicit: ', 843)
# ('number line: ', 983, 'number explicit: ', 843)
# ...
# ('number line: ', 36451, 'number explicit: ', 30867)
# ('number line: ', 36452, 'number explicit: ', 30867)
# ('number line: ', 36453, 'number explicit: ', 30868)
# ('number line: ', 36454, 'number explicit: ', 30868)
# ('number line: ', 36455, 'number explicit: ', 30868)
# ('number line: ', 36456, 'number explicit: ', 30868)
# ('number line: ', 36457, 'number explicit: ', 30869)
# ('number line: ', 36458, 'number explicit: ', 30869)
# ('number line: ', 36459, 'number explicit: ', 30869)
# ('number line: ', 36460, 'number explicit: ', 30874)
# ('number line: ', 36461, 'number explicit: ', 30874)
# ('number line: ', 36462, 'number explicit: ', 30874)
# ('number line: ', 36463, 'number explicit: ', 30874)
# ('number line: ', 36464, 'number explicit: ', 30874)
# ('number line: ', 36465, 'number explicit: ', 30874)
# ('number line: ', 36466, 'number explicit: ', 30874)
# ('number line: ', 36467, 'number explicit: ', 30874)
# ('number line: ', 36468, 'number explicit: ', 30874)
# ('number line: ', 36469, 'number explicit: ', 30874)
# ('number line: ', 36470, 'number explicit: ', 30874)
# ('number line: ', 36471, 'number explicit: ', 30874)
# ('number line: ', 36472, 'number explicit: ', 30874)
# ('number line: ', 36473, 'number explicit: ', 30874)
# ('number line: ', 36474, 'number explicit: ', 30897)
# ('number line: ', 36475, 'number explicit: ', 30897)
# ('number line: ', 36476, 'number explicit: ', 30897)
# ('number line: ', 36477, 'number explicit: ', 30897)
# ('number line: ', 36478, 'number explicit: ', 30899)
# ('number line: ', 36479, 'number explicit: ', 30899)
# ('number line: ', 36480, 'number explicit: ', 30901)
# ('number line: ', 36481, 'number explicit: ', 30901)
# ('number line: ', 36482, 'number explicit: ', 30901)
# ('number line: ', 36483, 'number explicit: ', 30902)
# ('number line: ', 36484, 'number explicit: ', 30902)
# ('number line: ', 36485, 'number explicit: ', 30902)
# ('number line: ', 36486, 'number explicit: ', 30902)
# ('number line: ', 36487, 'number explicit: ', 30902)
# ('number line: ', 36488, 'number explicit: ', 30902)
# ('number line: ', 36489, 'number explicit: ', 30902)
# ('number line: ', 36490, 'number explicit: ', 30902)
# ('number line: ', 36491, 'number explicit: ', 30902)
# ('number line: ', 36492, 'number explicit: ', 30902)
# ('number line: ', 36493, 'number explicit: ', 30905)
# ('number line: ', 36494, 'number explicit: ', 30907)
# ('number line: ', 36495, 'number explicit: ', 30911)
# ('number line: ', 36496, 'number explicit: ', 30911)
# ('number line: ', 36497, 'number explicit: ', 30911)
# ('number line: ', 36498, 'number explicit: ', 30911)
# ('number line: ', 36499, 'number explicit: ', 30912)
# ('number line: ', 36500, 'number explicit: ', 30912)
# ('number line: ', 36501, 'number explicit: ', 30912)
# ('number line: ', 36502, 'number explicit: ', 30912)
# ('number line: ', 36503, 'number explicit: ', 30912)
# ('number line: ', 36504, 'number explicit: ', 30912)
# ('number line: ', 36505, 'number explicit: ', 30913)
# ('number line: ', 36506, 'number explicit: ', 30915)
# ('number line: ', 36507, 'number explicit: ', 30915)
# ('number line: ', 36508, 'number explicit: ', 30915)
# ('number line: ', 36509, 'number explicit: ', 30915)
# ('number line: ', 36510, 'number explicit: ', 30915)
# ('number line: ', 36511, 'number explicit: ', 30915)
# ('number line: ', 36512, 'number explicit: ', 30915)
# ('number line: ', 36513, 'number explicit: ', 30915)
# ('number line: ', 36514, 'number explicit: ', 30915)
# ('number line: ', 36515, 'number explicit: ', 30915)
# ('number line: ', 36516, 'number explicit: ', 30915)
# ('number line: ', 36517, 'number explicit: ', 30918)
# ('number line: ', 36518, 'number explicit: ', 30918)
# ('number line: ', 36519, 'number explicit: ', 30918)
# ('number line: ', 36520, 'number explicit: ', 30918)
# ('number line: ', 36521, 'number explicit: ', 30918)
# ('number line: ', 36522, 'number explicit: ', 30918)
# ('number line: ', 36523, 'number explicit: ', 30918)
# ('number line: ', 36524, 'number explicit: ', 30918)
# ('number line: ', 36525, 'number explicit: ', 30918)
# ('number line: ', 36526, 'number explicit: ', 30923)
# ('number line: ', 36527, 'number explicit: ', 30923)
# ('number line: ', 36528, 'number explicit: ', 30924)
# ('number line: ', 36529, 'number explicit: ', 30924)
# ('number line: ', 36530, 'number explicit: ', 30924)
# ('number line: ', 36531, 'number explicit: ', 30924)
# ('number line: ', 36532, 'number explicit: ', 30924)
# ('number line: ', 36533, 'number explicit: ', 30924)
# ('number line: ', 36534, 'number explicit: ', 30924)
# ('number line: ', 36535, 'number explicit: ', 30924)
# ('number line: ', 36536, 'number explicit: ', 30926)
# ('number line: ', 36537, 'number explicit: ', 30926)
# ('number line: ', 36538, 'number explicit: ', 30926)
# ('number line: ', 36539, 'number explicit: ', 30926)
# ('number line: ', 36540, 'number explicit: ', 30926)
# ('number line: ', 36541, 'number explicit: ', 30926)
# ('number line: ', 36542, 'number explicit: ', 30926)
# ('number line: ', 36543, 'number explicit: ', 30926)
# ('number line: ', 36544, 'number explicit: ', 30926)
# ('number line: ', 36545, 'number explicit: ', 30937)
# ('number line: ', 36546, 'number explicit: ', 30937)
# ('number line: ', 36547, 'number explicit: ', 30938)
# ('number line: ', 36548, 'number explicit: ', 30938)
# ('number line: ', 36549, 'number explicit: ', 30938)
# ('number line: ', 36550, 'number explicit: ', 30938)
# ('number line: ', 36551, 'number explicit: ', 30938)
# ('number line: ', 36552, 'number explicit: ', 30939)
# ('number line: ', 36553, 'number explicit: ', 30939)
# ('number line: ', 36554, 'number explicit: ', 30940)
# ('number line: ', 36555, 'number explicit: ', 30940)
# ('number line: ', 36556, 'number explicit: ', 30940)
# ('number line: ', 36557, 'number explicit: ', 30940)
# ('number line: ', 36558, 'number explicit: ', 30941)
# ('number line: ', 36559, 'number explicit: ', 30941)
# ('number line: ', 36560, 'number explicit: ', 30942)
# ('number line: ', 36561, 'number explicit: ', 30942)
# ('number line: ', 36562, 'number explicit: ', 30944)
# ('number line: ', 36563, 'number explicit: ', 30945)
# ('number line: ', 36564, 'number explicit: ', 30945)
# ('number line: ', 36565, 'number explicit: ', 30945)
# ('number line: ', 36566, 'number explicit: ', 30945)
# ('number line: ', 36567, 'number explicit: ', 30945)
# ('number line: ', 36568, 'number explicit: ', 30945)
# ('number line: ', 36569, 'number explicit: ', 30945)
# ('number line: ', 36570, 'number explicit: ', 30945)
# ('number line: ', 36571, 'number explicit: ', 30945)
# ('number line: ', 36572, 'number explicit: ', 30945)
# ('number line: ', 36573, 'number explicit: ', 30945)
# ('number line: ', 36574, 'number explicit: ', 30948)
# ('number line: ', 36575, 'number explicit: ', 30948)
# ('number line: ', 36576, 'number explicit: ', 30948)
# ('number line: ', 36577, 'number explicit: ', 30950)
# ('number line: ', 36578, 'number explicit: ', 30950)
# ('number line: ', 36579, 'number explicit: ', 30950)
# ('number line: ', 36580, 'number explicit: ', 30952)
# ('number line: ', 36581, 'number explicit: ', 30952)
# ('number line: ', 36582, 'number explicit: ', 30952)
# ('number line: ', 36583, 'number explicit: ', 30952)
# ('number line: ', 36584, 'number explicit: ', 30954)
# ('number line: ', 36585, 'number explicit: ', 30954)
# ('number line: ', 36586, 'number explicit: ', 30954)
# ('number line: ', 36587, 'number explicit: ', 30955)
# ('number line: ', 36588, 'number explicit: ', 30959)
# ('number line: ', 36589, 'number explicit: ', 30959)
# ('number line: ', 36590, 'number explicit: ', 30959)
# ('number line: ', 36591, 'number explicit: ', 30959)
# ('number line: ', 36592, 'number explicit: ', 30959)
# ('number line: ', 36593, 'number explicit: ', 30960)
# ('number line: ', 36594, 'number explicit: ', 30960)
# ('number line: ', 36595, 'number explicit: ', 30960)
# ('number line: ', 36596, 'number explicit: ', 30960)
# ('number line: ', 36597, 'number explicit: ', 30960)
# ('number line: ', 36598, 'number explicit: ', 30960)
# ('number line: ', 36599, 'number explicit: ', 30960)
# ('number line: ', 36600, 'number explicit: ', 30960)
# ('number line: ', 36601, 'number explicit: ', 30960)
# ('number line: ', 36602, 'number explicit: ', 30965)
# ('number line: ', 36603, 'number explicit: ', 30965)
# ('number line: ', 36604, 'number explicit: ', 30965)
# ('number line: ', 36605, 'number explicit: ', 30965)
# ('number line: ', 36606, 'number explicit: ', 30970)
# ('number line: ', 36607, 'number explicit: ', 30970)
# ('number line: ', 36608, 'number explicit: ', 30970)
# ('number line: ', 36609, 'number explicit: ', 30971)
# ('number line: ', 36610, 'number explicit: ', 30971)
# ('number line: ', 36611, 'number explicit: ', 30971)
# ('number line: ', 36612, 'number explicit: ', 30971)
# ('number line: ', 36613, 'number explicit: ', 30977)
# ('number line: ', 36614, 'number explicit: ', 30977)
# ('number line: ', 36615, 'number explicit: ', 30977)
# ('number line: ', 36616, 'number explicit: ', 30979)
# ('number line: ', 36617, 'number explicit: ', 30979)
# ('number line: ', 36618, 'number explicit: ', 30980)
# ('number line: ', 36619, 'number explicit: ', 30980)
# ('number line: ', 36620, 'number explicit: ', 30980)
# ('number line: ', 36621, 'number explicit: ', 30980)
# ('number line: ', 36622, 'number explicit: ', 30980)
# ('number line: ', 36623, 'number explicit: ', 30981)
# ('number line: ', 36624, 'number explicit: ', 30983)
# ('number line: ', 36625, 'number explicit: ', 30984)
# ('number line: ', 36626, 'number explicit: ', 30984)
# ('number line: ', 36627, 'number explicit: ', 30984)
# ('number line: ', 36628, 'number explicit: ', 30984)
# ('number line: ', 36629, 'number explicit: ', 30985)
# ('number line: ', 36630, 'number explicit: ', 30985)
# ('number line: ', 36631, 'number explicit: ', 30985)
# ('number line: ', 36632, 'number explicit: ', 30985)
# ('number line: ', 36633, 'number explicit: ', 30985)
# ('number line: ', 36634, 'number explicit: ', 30987)
# ('number line: ', 36635, 'number explicit: ', 30987)
# ('number line: ', 36636, 'number explicit: ', 30987)
# ('number line: ', 36637, 'number explicit: ', 30987)
# ('number line: ', 36638, 'number explicit: ', 30987)
# ('number line: ', 36639, 'number explicit: ', 30987)
# ('number line: ', 36640, 'number explicit: ', 30988)
# ('number line: ', 36641, 'number explicit: ', 30988)
# ('number line: ', 36642, 'number explicit: ', 30988)
# ('number line: ', 36643, 'number explicit: ', 30988)
# ('number line: ', 36644, 'number explicit: ', 30988)
# ('number line: ', 36645, 'number explicit: ', 30988)
# ('number line: ', 36646, 'number explicit: ', 30988)
# ('number line: ', 36647, 'number explicit: ', 30988)
# ('number line: ', 36648, 'number explicit: ', 30988)
# ('number line: ', 36649, 'number explicit: ', 30988)
# ('number line: ', 36650, 'number explicit: ', 30988)
# ('number line: ', 36651, 'number explicit: ', 30989)
# ('number line: ', 36652, 'number explicit: ', 30989)
# ('number line: ', 36653, 'number explicit: ', 30989)
# ('number line: ', 36654, 'number explicit: ', 30989)
# ('number line: ', 36655, 'number explicit: ', 30989)
# ('number line: ', 36656, 'number explicit: ', 30989)
# ('number line: ', 36657, 'number explicit: ', 30989)
# ('number line: ', 36658, 'number explicit: ', 30989)
# ('number line: ', 36659, 'number explicit: ', 30989)
# ('number line: ', 36660, 'number explicit: ', 30989)
# ('number line: ', 36661, 'number explicit: ', 30990)
# ('number line: ', 36662, 'number explicit: ', 30990)
# ('number line: ', 36663, 'number explicit: ', 30991)
# ('number line: ', 36664, 'number explicit: ', 30998)
# ('number line: ', 36665, 'number explicit: ', 30998)
# ('number line: ', 36666, 'number explicit: ', 30998)
# ('number line: ', 36667, 'number explicit: ', 30998)
# ('number line: ', 36668, 'number explicit: ', 30998)
# ('number line: ', 36669, 'number explicit: ', 30998)
# ('number line: ', 36670, 'number explicit: ', 30998)
# ('number line: ', 36671, 'number explicit: ', 31006)
# ('number line: ', 36672, 'number explicit: ', 31006)
# ('number line: ', 36673, 'number explicit: ', 31006)
# ('number line: ', 36674, 'number explicit: ', 31006)
# ('number line: ', 36675, 'number explicit: ', 31006)
# ('number line: ', 36676, 'number explicit: ', 31007)
# ('number line: ', 36677, 'number explicit: ', 31007)
# ('number line: ', 36678, 'number explicit: ', 31008)
# ('number line: ', 36679, 'number explicit: ', 31008)
# ('number line: ', 36680, 'number explicit: ', 31008)
# ('number line: ', 36681, 'number explicit: ', 31008)
# ('number line: ', 36682, 'number explicit: ', 31008)
# ('number line: ', 36683, 'number explicit: ', 31008)
# ('number line: ', 36684, 'number explicit: ', 31009)
# ('number line: ', 36685, 'number explicit: ', 31009)
# ('number line: ', 36686, 'number explicit: ', 31011)
# ('number line: ', 36687, 'number explicit: ', 31011)
# ('number line: ', 36688, 'number explicit: ', 31011)
# ('number line: ', 36689, 'number explicit: ', 31011)
# ('number line: ', 36690, 'number explicit: ', 31011)
# ('number line: ', 36691, 'number explicit: ', 31011)
# ('number line: ', 36692, 'number explicit: ', 31011)
# ('number line: ', 36693, 'number explicit: ', 31011)
# ('number line: ', 36694, 'number explicit: ', 31014)
# ('number line: ', 36695, 'number explicit: ', 31014)
# ('number line: ', 36696, 'number explicit: ', 31014)
# ('number line: ', 36697, 'number explicit: ', 31014)
# ('number line: ', 36698, 'number explicit: ', 31014)
# ('number line: ', 36699, 'number explicit: ', 31014)
# ('number line: ', 36700, 'number explicit: ', 31014)
# ('number line: ', 36701, 'number explicit: ', 31015)
# ('number line: ', 36702, 'number explicit: ', 31016)
# ('number line: ', 36703, 'number explicit: ', 31016)
# ('number line: ', 36704, 'number explicit: ', 31016)
# ('number line: ', 36705, 'number explicit: ', 31016)
# ('number line: ', 36706, 'number explicit: ', 31016)
# ('number line: ', 36707, 'number explicit: ', 31021)
# ('number line: ', 36708, 'number explicit: ', 31022)
# ('number line: ', 36709, 'number explicit: ', 31023)
# ('number line: ', 36710, 'number explicit: ', 31023)
# ('number line: ', 36711, 'number explicit: ', 31024)
# ('number line: ', 36712, 'number explicit: ', 31028)
# ('number line: ', 36713, 'number explicit: ', 31040)
# ('number line: ', 36714, 'number explicit: ', 31040)
# ('number line: ', 36715, 'number explicit: ', 31041)
# ('number line: ', 36716, 'number explicit: ', 31041)
# ('number line: ', 36717, 'number explicit: ', 31041)
# ('number line: ', 36718, 'number explicit: ', 31041)
# ('number line: ', 36719, 'number explicit: ', 31041)
# ('number line: ', 36720, 'number explicit: ', 31042)
# ('number line: ', 36721, 'number explicit: ', 31042)
# ('number line: ', 36722, 'number explicit: ', 31042)
# ('number line: ', 36723, 'number explicit: ', 31042)
# ('number line: ', 36724, 'number explicit: ', 31042)
# ('number line: ', 36725, 'number explicit: ', 31042)
# ('number line: ', 36726, 'number explicit: ', 31043)
# ('number line: ', 36727, 'number explicit: ', 31043)
# ('number line: ', 36728, 'number explicit: ', 31049)
# ('number line: ', 36729, 'number explicit: ', 31049)
# ('number line: ', 36730, 'number explicit: ', 31049)
# ('number line: ', 36731, 'number explicit: ', 31049)
# ('number line: ', 36732, 'number explicit: ', 31049)
# ('number line: ', 36733, 'number explicit: ', 31049)
# ('number line: ', 36734, 'number explicit: ', 31050)
# ('number line: ', 36735, 'number explicit: ', 31052)
# ('number line: ', 36736, 'number explicit: ', 31052)
# ('number line: ', 36737, 'number explicit: ', 31053)
# ('number line: ', 36738, 'number explicit: ', 31053)
# ('number line: ', 36739, 'number explicit: ', 31053)
# ('number line: ', 36740, 'number explicit: ', 31053)
# ('number line: ', 36741, 'number explicit: ', 31053)
# ('number line: ', 36742, 'number explicit: ', 31053)
# ('number line: ', 36743, 'number explicit: ', 31053)
# ('number line: ', 36744, 'number explicit: ', 31053)
# ('number line: ', 36745, 'number explicit: ', 31053)
# ('number line: ', 36746, 'number explicit: ', 31053)
# ('number line: ', 36747, 'number explicit: ', 31053)
# ('number line: ', 36748, 'number explicit: ', 31053)
# ('number line: ', 36749, 'number explicit: ', 31053)
# ('number line: ', 36750, 'number explicit: ', 31053)
# ('number line: ', 36751, 'number explicit: ', 31053)

# %%
### Using for splitting test for three datasets.

# %%
import csv
from src import settings
retail_rocket_root_path = settings.DATA_ROOT_PATH + 'site_data/recobell/'
file1 = open(retail_rocket_root_path + "ratings_new_ids.txt", "r")

test_file = retail_rocket_root_path + "ratings_test.txt"

number_explicit = 0
test ={}
for line in file1.readlines():
    number_line += 1
    line = line.strip()
    elements = line.split("|")
    item_ids = elements[1].strip()[1:-1]
    itemids =[]
    interactids= []
    
    for item_id in item_ids.split(","):
        itemids.append(int(item_id.strip()))
        
    interacts = elements[2].strip()[1:-1]
    for interact in interacts.split(","):
        val = interact.strip()
        interactids.append(int(val))
    
    if interactids[-1] == 1:
        test[int(elements[0].strip())] =itemids[-1]
    
print "Dict:", test
print "Last: ",len(test.keys())

print("Init writing")
writefile = open(test_file, "w")
csv_writer = csv.writer(writefile, delimiter=',', quotechar='', quoting=csv.QUOTE_NONE)
for uid in test:
    csv_writer.writerow([uid, test[uid]])
# Out:
# Dict: {32768: 1338, 131073: 479, 196613: 111, 196614: 2130, 7: 198, 128892: 14088, 65545: 342, 32778: 353, 65548: 641, 32781: 479, 48010: 3764, 32784: 6287, 72015: 2060, 65557: 4615, 98327: 586, 65560: 6140, 131098: 1386, 98331: 80330, 131100: 3685, 32799: 1168, 76380: 69644, 65569: 393, 32804: 1126, 163877: 1168, 131114: 3385, 131116: 941, 163886: 305, 196656: 9620, 196658: 4984, 32819: 67, 52: 421, 38238: 10980, 98358: 877, 131081: 5905, 163897: 752, 65594: 48, 196667: 1664, 65596: 3234, 32830: 1168, 196671: 5601, 131137: 12046, 65605: 123, 98374: 2047, 54625: 1768, 72: 184, 12: 2572, 32845: 7067, 163918: 1473, 79: 251, 163920: 22, 131156: 393, 196693: 8887, 163929: 8225, 114703: 1676, 163933: 1928, 98398: 3845, 131088: 1104, 98404: 14678, 5478: 869, 32870: 23766, 65639: 393, 196712: 481, 131177: 1444, 65642: 1713, 107: 3381, 109: 357, 65651: 448, 98422: 242, 98423: 405, 196728: 4835, 196730: 2970, 65659: 124, 65660: 393, 98431: 2747, 196737: 8, 163970: 675, 131: 1046, 98436: 31, 27329: 2398, 131208: 2495, 5484: 1238, 138: 90, 196748: 1438, 60098: 6303, 131215: 16374, 65681: 393, 147: 1385, 98452: 237, 32917: 6314, 65688: 1483, 154: 225, 98459: 31786, 98330: 6094, 32930: 17015, 147483: 960, 164: 22, 21873: 992, 168: 1928, 196636: 3620, 29466: 641, 98475: 50, 98479: 48030, 196784: 966, 191176: 393, 98485: 358, 196791: 3341, 131256: 342, 168040: 9629, 187: 1104, 98493: 24, 103797: 645, 193: 1532, 164035: 353, 164036: 456, 185718: 308, 202: 1545, 32971: 12299, 164044: 1855, 65741: 357, 196815: 10757, 196820: 237, 65750: 191, 134216: 3911, 169780: 691, 164060: 1071, 222: 1622, 223: 1768, 32993: 529, 131300: 1768, 196837: 1597, 98534: 357, 104756: 9345, 65768: 393, 33001: 24, 114727: 87002, 33005: 124, 131310: 1317, 44301: 84, 65779: 53, 98551: 928, 24013: 20444, 98556: 1768, 164093: 3919, 164094: 1519, 258: 1168, 196867: 432, 196868: 223, 65799: 1182, 28589: 8233, 33035: 237, 38274: 33, 98574: 1753, 196879: 393, 272: 670, 98578: 467, 87427: 8619, 114734: 3746, 283: 1972, 196897: 752, 291: 1444, 292: 247, 202118: 305, 131366: 7747, 65831: 8225, 131368: 207, 191196: 1933, 164144: 1502, 196913: 962, 10974: 8844, 185737: 64, 153632: 47, 65851: 39460, 196924: 3740, 120202: 5324, 46929: 1897, 53: 425, 320: 393, 104759: 1337, 65858: 196, 65859: 1545, 131397: 760, 196935: 685, 164168: 941, 164170: 21940, 98359: 111, 33100: 53, 164173: 84, 33102: 1597, 336: 2305, 131129: 394, 98648: 2676, 89484: 2007, 164188: 3411, 33118: 1906, 60133: 50, 131426: 1727, 204053: 2335, 98662: 1260, 98663: 405, 98664: 7271, 196970: 1222, 131436: 5233, 33133: 611, 196974: 64, 65903: 1414, 370: 383, 131443: 1085, 164212: 4261, 98366: 1386, 109289: 1147, 98684: 406, 43754: 1685, 33151: 960, 98688: 1190, 131457: 17626, 142059: 1444, 196996: 198, 196998: 6827, 33160: 2299, 197001: 1063, 65931: 4614, 197006: 356, 131471: 626, 197009: 570, 186626: 3489, 164247: 50, 33176: 140, 414: 1463, 98373: 36, 197024: 84, 33187: 237, 98724: 752, 65957: 206, 422: 752, 197032: 8820, 164265: 191, 38301: 342, 98736: 30, 98737: 123, 131508: 660, 73: 280, 33209: 18935, 33211: 78, 164285: 11945, 164287: 941, 30336: 1695, 98753: 752, 131524: 1031, 98758: 703, 5537: 14539, 131529: 3319, 82941: 2786, 197068: 2299, 131533: 3, 65998: 73, 33231: 5584, 60152: 481, 66002: 411, 470: 23772, 197080: 24, 33241: 1118, 164316: 1545, 66013: 173, 197086: 22, 185765: 529, 164320: 3783, 196688: 38182, 164322: 693, 483: 237, 67781: 2037, 490: 223, 66028: 481, 197102: 24, 158461: 410, 131569: 1747, 46620: 1301, 164339: 2047, 33272: 10988, 505: 83, 98811: 73, 66044: 6112, 509: 78, 131584: 9207, 33284: 432, 33285: 10254, 164358: 64, 66055: 140, 197128: 9117, 197129: 4280, 66060: 2793, 198603: 102, 66063: 1515, 158467: 923, 197140: 1444, 534: 76, 66073: 7051, 103855: 64, 33308: 8684, 98845: 6790, 1109: 38, 187097: 2037, 66081: 377, 131618: 643, 98851: 1331, 76550: 3764, 33319: 23, 131624: 7723, 33321: 450, 197162: 641, 13097: 481, 197169: 1294, 563: 225, 196702: 670, 33334: 356, 567: 1182, 136410: 84, 1316 ...
# Last:  17568
# Init writing

# %%
# writing into train file.
import csv
from src import settings
retail_rocket_root_path = settings.DATA_ROOT_PATH + 'site_data/retail_rocket/'
file1 = open(retail_rocket_root_path + "ratings_new_ids.txt", "r")

train_file = retail_rocket_root_path + "ratings_train.txt"

number_explicit = 0
train_items ={}
train_interacts ={}
for line in file1.readlines():
    number_line += 1
    line = line.strip()
    elements = line.split("|")
    
    item_ids = elements[1].strip()[1:-1]
    itemids =[]
    interactids= []
    
    for item_id in item_ids.split(","):
        itemids.append(int(item_id.strip())) # list
        
    interacts = elements[2].strip()[1:-1]
    for interact in interacts.split(","):
        val = interact.strip()
        interactids.append(int(val)) # list

    train_items[int(elements[0].strip())] =itemids[:-1]
    train_interacts[int(elements[0].strip())] = interactids[:-1]
#     print line
#     print train_items
#     print train_interacts
#     break
# print "Dict:", train
print "Last: ",len(train_items.keys())

print("Init writing")
writefile = open(train_file, "w")
csv_writer = csv.writer(writefile, delimiter='|', quotechar='', quoting=csv.QUOTE_NONE)
for uid in train_items:
    csv_writer.writerow([uid, train_items[uid], train_interacts[uid]])
# Out:
# Last:  36751
# Init writing
